# %%
# !pip install tensorflow-addons
# !pip install wheel
# !pip install pandas
# !pip install opencv-python
# !pip install matplotlib
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: tensorflow-addons in c:\users\20101621\.conda\envs\new_env\lib\site-packages (0.20.0)
# Requirement already satisfied: packaging in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from tensorflow-addons) (23.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from tensorflow-addons) (2.13.3)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# Requirement already satisfied: wheel in c:\users\20101621\.conda\envs\new_env\lib\site-packages (0.35.1)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# Requirement already satisfied: pandas in c:\users\20101621\.conda\envs\new_env\lib\site-packages (2.0.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# Requirement already satisfied: opencv-python in c:\users\20101621\.conda\envs\new_env\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from opencv-python) (1.23.5)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# Requirement already satisfied: matplotlib in c:\users\20101621\.conda\envs\new_env\lib\site-packages (3.7.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# C:\Users\20101621\.conda\envs\new_env\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# C:\Users\20101621\.conda\envs\new_env\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.10.0 and strictly below 2.13.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.6.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
train_path = "./Downloads/Final_Train_Test_thesis2.0/train"
test_path = "./Downloads/Final_Train_Test_thesis2.0/test"
x_train=[]  

for folder in os.listdir(train_path):

    sub_path=train_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_train.append(img_arr)

x_test=[]

for folder in os.listdir(test_path):

    sub_path=test_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_test.append(img_arr)

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128, 128),
                                                 batch_size = 500,
                                                 class_mode = 'sparse')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (128, 128),
                                            batch_size = 500,
                                            class_mode = 'sparse')

y_train=training_set.classes
y_test=test_set.classes

num_classes  = 3
input_shape  = (128, 128, 3)

y_train = y_train.reshape((len(y_train), 1))
y_test = y_test.reshape((len(y_test), 1))
# Out:
# Found 9921 images belonging to 3 classes.
# Found 1420 images belonging to 3 classes.

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128, 128),
                                                 batch_size = 32,
                                                 class_mode = 'sparse')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (128, 128),
                                            batch_size = 32,
                                            class_mode = 'sparse')

y_train=training_set.classes
y_test=test_set.classes

num_classes  = 3
input_shape  = (128, 128, 3)

y_train = y_train.reshape((len(y_train), 1))
y_test = y_test.reshape((len(y_test), 1))
# Out:
# Found 9921 images belonging to 3 classes.
# Found 1420 images belonging to 3 classes.

# %%
# !pip install -U -q tensorflow-addons
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np
# Out:
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)

# %%
positional_emb = True
conv_layers = 2
projection_dim = 128

num_heads = 2
transformer_units = [
    projection_dim,
    projection_dim,
]
transformer_layers = 2
stochastic_depth_rate = 0.1

learning_rate = 0.001
weight_decay = 0.05
batch_size = 32
num_epochs = 200
image_size = 128

# %%
num_classes  = 3
input_shape  = (128, 128, 3)

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (9921, 128, 128, 3) - y_train shape: (9921, 3)
# x_test shape: (1420, 128, 128, 3) - y_test shape: (1420, 3)

# %%
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super().__init__(**kwargs)

        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )

        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]

            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %%
# Referred from: github.com:rwightman/pytorch-image-models.
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prop

    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (tf.shape(x).shape[0] - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
# Note the rescaling layer. These layers have pre-defined inference behavior.
data_n = keras.Sequential(
    [
        layers.Rescaling(scale=1.0 / 255),
        layers.RandomCrop(image_size, image_size),
    ],
    name="data",
)

# %%
def create_cct_model(
    image_size=image_size,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):

    inputs = layers.Input(input_shape)

    # Augment data.
    data = data_n(inputs)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(data)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)

        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)

        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)

        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(num_classes)(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(
            from_logits=True, label_smoothing=0.1
        ),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "./tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history


cct_model = create_cct_model()
history = run_experiment(cct_model)
# Out:
# Epoch 1/200
# 279/279 [==============================] - 33s 98ms/step - loss: 0.7190 - accuracy: 0.7655 - top-5-accuracy: 1.0000 - val_loss: 0.7356 - val_accuracy: 0.7885 - val_top-5-accuracy: 1.0000
# Epoch 2/200
# 279/279 [==============================] - 27s 96ms/step - loss: 0.5318 - accuracy: 0.8707 - top-5-accuracy: 1.0000 - val_loss: 0.8130 - val_accuracy: 0.7654 - val_top-5-accuracy: 1.0000
# Epoch 3/200
# 279/279 [==============================] - 27s 97ms/step - loss: 0.4836 - accuracy: 0.8987 - top-5-accuracy: 1.0000 - val_loss: 0.9211 - val_accuracy: 0.7694 - val_top-5-accuracy: 1.0000
# Epoch 4/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.4692 - accuracy: 0.9043 - top-5-accuracy: 1.0000 - val_loss: 0.7248 - val_accuracy: 0.7915 - val_top-5-accuracy: 1.0000
# Epoch 5/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.4513 - accuracy: 0.9151 - top-5-accuracy: 1.0000 - val_loss: 0.6082 - val_accuracy: 0.8197 - val_top-5-accuracy: 1.0000
# Epoch 6/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.4400 - accuracy: 0.9195 - top-5-accuracy: 1.0000 - val_loss: 0.6584 - val_accuracy: 0.8056 - val_top-5-accuracy: 1.0000
# Epoch 7/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.4262 - accuracy: 0.9285 - top-5-accuracy: 1.0000 - val_loss: 0.5962 - val_accuracy: 0.8258 - val_top-5-accuracy: 1.0000
# Epoch 8/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.4141 - accuracy: 0.9334 - top-5-accuracy: 1.0000 - val_loss: 0.5226 - val_accuracy: 0.8288 - val_top-5-accuracy: 1.0000
# Epoch 9/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.4104 - accuracy: 0.9387 - top-5-accuracy: 1.0000 - val_loss: 0.6387 - val_accuracy: 0.8288 - val_top-5-accuracy: 1.0000
# Epoch 10/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3977 - accuracy: 0.9449 - top-5-accuracy: 1.0000 - val_loss: 0.5626 - val_accuracy: 0.8479 - val_top-5-accuracy: 1.0000
# Epoch 11/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3847 - accuracy: 0.9536 - top-5-accuracy: 1.0000 - val_loss: 0.6378 - val_accuracy: 0.8298 - val_top-5-accuracy: 1.0000
# Epoch 12/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3776 - accuracy: 0.9551 - top-5-accuracy: 1.0000 - val_loss: 0.5462 - val_accuracy: 0.8520 - val_top-5-accuracy: 1.0000
# Epoch 13/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3694 - accuracy: 0.9616 - top-5-accuracy: 1.0000 - val_loss: 0.8282 - val_accuracy: 0.7946 - val_top-5-accuracy: 1.0000
# Epoch 14/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3662 - accuracy: 0.9639 - top-5-accuracy: 1.0000 - val_loss: 0.4502 - val_accuracy: 0.8892 - val_top-5-accuracy: 1.0000
# Epoch 15/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3612 - accuracy: 0.9670 - top-5-accuracy: 1.0000 - val_loss: 0.5782 - val_accuracy: 0.8459 - val_top-5-accuracy: 1.0000
# Epoch 16/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3548 - accuracy: 0.9691 - top-5-accuracy: 1.0000 - val_loss: 0.5460 - val_accuracy: 0.8560 - val_top-5-accuracy: 1.0000
# Epoch 17/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3569 - accuracy: 0.9695 - top-5-accuracy: 1.0000 - val_loss: 0.3667 - val_accuracy: 0.9537 - val_top-5-accuracy: 1.0000
# Epoch 18/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3422 - accuracy: 0.9758 - top-5-accuracy: 1.0000 - val_loss: 0.4279 - val_accuracy: 0.9194 - val_top-5-accuracy: 1.0000
# Epoch 19/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3535 - accuracy: 0.9700 - top-5-accuracy: 1.0000 - val_loss: 0.5384 - val_accuracy: 0.8540 - val_top-5-accuracy: 1.0000
# Epoch 20/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3558 - accuracy: 0.9668 - top-5-accuracy: 1.0000 - val_loss: 0.5701 - val_accuracy: 0.8640 - val_top-5-accuracy: 1.0000
# Epoch 21/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3349 - accuracy: 0.9800 - top-5-accuracy: 1.0000 - val_loss: 0.8509 - val_accuracy: 0.7825 - val_top-5-accuracy: 1.0000
# Epoch 22/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3393 - accuracy: 0.9773 - top-5-accuracy: 1.0000 - val_loss: 0.5377 - val_accuracy: 0.8781 - val_top-5-accuracy: 1.0000
# Epoch 23/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3360 - accuracy: 0.9780 - top-5-accuracy: 1.0000 - val_loss: 0.5274 - val_accuracy: 0.8671 - val_top-5-accuracy: 1.0000
# Epoch 24/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3288 - accuracy: 0.9819 - top-5-accuracy: 1.0000 - val_loss: 0.3816 - val_accuracy: 0.9446 - val_top-5-accuracy: 1.0000
# Epoch 25/200
# 279/279 [==============================] - 27s 96ms/step - loss: 0.3363 - accuracy: 0.9794 - top-5-accuracy: 1.0000 - val_loss: 0.8311 - val_accuracy: 0.8107 - val_top-5-accuracy: 1.0000
# Epoch 26/200
# 279/279 [==============================] - 27s 98ms/step - loss: 0.3383 - accuracy: 0.9760 - top-5-accuracy: 1.0000 - val_loss: 0.3636 - val_accuracy: 0.9486 - val_top-5-accuracy: 1.0000
# Epoch 27/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3311 - accuracy: 0.9804 - top-5-accuracy: 1.0000 - val_loss: 0.3477 - val_accuracy: 0.9597 - val_top-5-accuracy: 1.0000
# Epoch 28/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3231 - accuracy: 0.9849 - top-5-accuracy: 1.0000 - val_loss: 0.3502 - val_accuracy: 0.9587 - val_top-5-accuracy: 1.0000
# Epoch 29/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3299 - accuracy: 0.9821 - top-5-accuracy: 1.0000 - val_loss: 0.3278 - val_accuracy: 0.9839 - val_top-5-accuracy: 1.0000
# Epoch 30/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3299 - accuracy: 0.9804 - top-5-accuracy: 1.0000 - val_loss: 0.3429 - val_accuracy: 0.9758 - val_top-5-accuracy: 1.0000
# Epoch 31/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3340 - accuracy: 0.9793 - top-5-accuracy: 1.0000 - val_loss: 0.9384 - val_accuracy: 0.5025 - val_top-5-accuracy: 1.0000
# Epoch 32/200
# 279/279 [==============================] - 27s 96ms/step - loss: 0.3284 - accuracy: 0.9831 - top-5-accuracy: 1.0000 - val_loss: 0.5309 - val_accuracy: 0.8822 - val_top-5-accuracy: 1.0000
# Epoch 33/200
# 279/279 [==============================] - 27s 98ms/step - loss: 0.3229 - accuracy: 0.9842 - top-5-accuracy: 1.0000 - val_loss: 0.4760 - val_accuracy: 0.9144 - val_top-5-accuracy: 1.0000
# Epoch 34/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3380 - accuracy: 0.9756 - top-5-accuracy: 1.0000 - val_loss: 0.3267 - val_accuracy: 0.9859 - val_top-5-accuracy: 1.0000
# Epoch 35/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3174 - accuracy: 0.9884 - top-5-accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.9426 - val_top-5-accuracy: 1.0000
# Epoch 36/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3229 - accuracy: 0.9838 - top-5-accuracy: 1.0000 - val_loss: 0.5316 - val_accuracy: 0.8671 - val_top-5-accuracy: 1.0000
# Epoch 37/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3178 - accuracy: 0.9888 - top-5-accuracy: 1.0000 - val_loss: 0.4519 - val_accuracy: 0.8983 - val_top-5-accuracy: 1.0000
# Epoch 38/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3188 - accuracy: 0.9866 - top-5-accuracy: 1.0000 - val_loss: 0.6100 - val_accuracy: 0.8359 - val_top-5-accuracy: 1.0000
# Epoch 39/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3205 - accuracy: 0.9864 - top-5-accuracy: 1.0000 - val_loss: 0.6806 - val_accuracy: 0.8409 - val_top-5-accuracy: 1.0000
# Epoch 40/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3202 - accuracy: 0.9875 - top-5-accuracy: 1.0000 - val_loss: 0.5025 - val_accuracy: 0.8963 - val_top-5-accuracy: 1.0000
# Epoch 41/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3103 - accuracy: 0.9908 - top-5-accuracy: 1.0000 - val_loss: 0.5823 - val_accuracy: 0.8550 - val_top-5-accuracy: 1.0000
# Epoch 42/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3412 - accuracy: 0.9755 - top-5-accuracy: 1.0000 - val_loss: 0.3127 - val_accuracy: 0.9899 - val_top-5-accuracy: 1.0000
# Epoch 43/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3151 - accuracy: 0.9888 - top-5-accuracy: 1.0000 - val_loss: 0.5375 - val_accuracy: 0.8832 - val_top-5-accuracy: 1.0000
# Epoch 44/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3278 - accuracy: 0.9812 - top-5-accuracy: 1.0000 - val_loss: 0.6324 - val_accuracy: 0.8409 - val_top-5-accuracy: 1.0000
# Epoch 45/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3096 - accuracy: 0.9916 - top-5-accuracy: 1.0000 - val_loss: 0.4527 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 46/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3151 - accuracy: 0.9887 - top-5-accuracy: 1.0000 - val_loss: 0.3097 - val_accuracy: 0.9940 - val_top-5-accuracy: 1.0000
# Epoch 47/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3216 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.3321 - val_accuracy: 0.9758 - val_top-5-accuracy: 1.0000
# Epoch 48/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3180 - accuracy: 0.9875 - top-5-accuracy: 1.0000 - val_loss: 0.3459 - val_accuracy: 0.9698 - val_top-5-accuracy: 1.0000
# Epoch 49/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3244 - accuracy: 0.9834 - top-5-accuracy: 1.0000 - val_loss: 0.3391 - val_accuracy: 0.9718 - val_top-5-accuracy: 1.0000
# Epoch 50/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3180 - accuracy: 0.9869 - top-5-accuracy: 1.0000 - val_loss: 0.4904 - val_accuracy: 0.9164 - val_top-5-accuracy: 1.0000
# Epoch 51/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3161 - accuracy: 0.9889 - top-5-accuracy: 1.0000 - val_loss: 0.4044 - val_accuracy: 0.9476 - val_top-5-accuracy: 1.0000
# Epoch 52/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3092 - accuracy: 0.9920 - top-5-accuracy: 1.0000 - val_loss: 0.4663 - val_accuracy: 0.8902 - val_top-5-accuracy: 1.0000
# Epoch 53/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3199 - accuracy: 0.9861 - top-5-accuracy: 1.0000 - val_loss: 0.6155 - val_accuracy: 0.8620 - val_top-5-accuracy: 1.0000
# Epoch 54/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3138 - accuracy: 0.9895 - top-5-accuracy: 1.0000 - val_loss: 0.3780 - val_accuracy: 0.9567 - val_top-5-accuracy: 1.0000
# Epoch 55/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3148 - accuracy: 0.9891 - top-5-accuracy: 1.0000 - val_loss: 0.5867 - val_accuracy: 0.8681 - val_top-5-accuracy: 1.0000
# Epoch 56/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3123 - accuracy: 0.9890 - top-5-accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.8983 - val_top-5-accuracy: 1.0000
# Epoch 57/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3216 - accuracy: 0.9854 - top-5-accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9930 - val_top-5-accuracy: 1.0000
# Epoch 58/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3056 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.4384 - val_accuracy: 0.9275 - val_top-5-accuracy: 1.0000
# Epoch 59/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3173 - accuracy: 0.9870 - top-5-accuracy: 1.0000 - val_loss: 0.3083 - val_accuracy: 0.9909 - val_top-5-accuracy: 1.0000
# Epoch 60/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3026 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 0.3526 - val_accuracy: 0.9648 - val_top-5-accuracy: 1.0000
# Epoch 61/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3221 - accuracy: 0.9843 - top-5-accuracy: 1.0000 - val_loss: 0.3999 - val_accuracy: 0.9416 - val_top-5-accuracy: 1.0000
# Epoch 62/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3111 - accuracy: 0.9903 - top-5-accuracy: 1.0000 - val_loss: 0.3574 - val_accuracy: 0.9617 - val_top-5-accuracy: 1.0000
# Epoch 63/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3361 - accuracy: 0.9791 - top-5-accuracy: 1.0000 - val_loss: 0.3672 - val_accuracy: 0.9567 - val_top-5-accuracy: 1.0000
# Epoch 64/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3152 - accuracy: 0.9881 - top-5-accuracy: 1.0000 - val_loss: 0.3233 - val_accuracy: 0.9819 - val_top-5-accuracy: 1.0000
# Epoch 65/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3078 - accuracy: 0.9916 - top-5-accuracy: 1.0000 - val_loss: 0.3811 - val_accuracy: 0.9547 - val_top-5-accuracy: 1.0000
# Epoch 66/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3101 - accuracy: 0.9906 - top-5-accuracy: 1.0000 - val_loss: 0.3416 - val_accuracy: 0.9728 - val_top-5-accuracy: 1.0000
# Epoch 67/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3116 - accuracy: 0.9899 - top-5-accuracy: 1.0000 - val_loss: 0.3794 - val_accuracy: 0.9547 - val_top-5-accuracy: 1.0000
# Epoch 68/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3148 - accuracy: 0.9890 - top-5-accuracy: 1.0000 - val_loss: 0.3360 - val_accuracy: 0.9768 - val_top-5-accuracy: 1.0000
# Epoch 69/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3187 - accuracy: 0.9864 - top-5-accuracy: 1.0000 - val_loss: 0.3763 - val_accuracy: 0.9537 - val_top-5-accuracy: 1.0000
# Epoch 70/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2996 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.3133 - val_accuracy: 0.9879 - val_top-5-accuracy: 1.0000
# Epoch 71/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3368 - accuracy: 0.9782 - top-5-accuracy: 1.0000 - val_loss: 0.3074 - val_accuracy: 0.9930 - val_top-5-accuracy: 1.0000
# Epoch 72/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3025 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.3473 - val_accuracy: 0.9668 - val_top-5-accuracy: 1.0000
# Epoch 73/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3080 - accuracy: 0.9925 - top-5-accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.8761 - val_top-5-accuracy: 1.0000
# Epoch 74/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3085 - accuracy: 0.9910 - top-5-accuracy: 1.0000 - val_loss: 0.3603 - val_accuracy: 0.9587 - val_top-5-accuracy: 1.0000
# Epoch 75/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3234 - accuracy: 0.9838 - top-5-accuracy: 1.0000 - val_loss: 0.4764 - val_accuracy: 0.9023 - val_top-5-accuracy: 1.0000
# Epoch 76/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3206 - accuracy: 0.9845 - top-5-accuracy: 1.0000 - val_loss: 0.3859 - val_accuracy: 0.9476 - val_top-5-accuracy: 1.0000
# Epoch 77/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3059 - accuracy: 0.9933 - top-5-accuracy: 1.0000 - val_loss: 0.3018 - val_accuracy: 0.9990 - val_top-5-accuracy: 1.0000
# Epoch 78/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3118 - accuracy: 0.9899 - top-5-accuracy: 1.0000 - val_loss: 0.3448 - val_accuracy: 0.9718 - val_top-5-accuracy: 1.0000
# Epoch 79/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3138 - accuracy: 0.9899 - top-5-accuracy: 1.0000 - val_loss: 0.4266 - val_accuracy: 0.9345 - val_top-5-accuracy: 1.0000
# Epoch 80/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3209 - accuracy: 0.9853 - top-5-accuracy: 1.0000 - val_loss: 0.7589 - val_accuracy: 0.8056 - val_top-5-accuracy: 1.0000
# Epoch 81/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3014 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 0.3438 - val_accuracy: 0.9698 - val_top-5-accuracy: 1.0000
# Epoch 82/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3103 - accuracy: 0.9907 - top-5-accuracy: 1.0000 - val_loss: 0.4232 - val_accuracy: 0.9275 - val_top-5-accuracy: 1.0000
# Epoch 83/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3062 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.2990 - val_accuracy: 0.9960 - val_top-5-accuracy: 1.0000
# Epoch 84/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3223 - accuracy: 0.9851 - top-5-accuracy: 1.0000 - val_loss: 0.3773 - val_accuracy: 0.9476 - val_top-5-accuracy: 1.0000
# Epoch 85/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3012 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.3237 - val_accuracy: 0.9809 - val_top-5-accuracy: 1.0000
# Epoch 86/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3098 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.5888 - val_accuracy: 0.8671 - val_top-5-accuracy: 1.0000
# Epoch 87/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3160 - accuracy: 0.9868 - top-5-accuracy: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9970 - val_top-5-accuracy: 1.0000
# Epoch 88/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3042 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 0.7372 - val_accuracy: 0.8288 - val_top-5-accuracy: 1.0000
# Epoch 89/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3184 - accuracy: 0.9856 - top-5-accuracy: 1.0000 - val_loss: 0.4925 - val_accuracy: 0.9154 - val_top-5-accuracy: 1.0000
# Epoch 90/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3029 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 0.3461 - val_accuracy: 0.9758 - val_top-5-accuracy: 1.0000
# Epoch 91/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3058 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.4600 - val_accuracy: 0.9235 - val_top-5-accuracy: 1.0000
# Epoch 92/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3216 - accuracy: 0.9849 - top-5-accuracy: 1.0000 - val_loss: 0.3573 - val_accuracy: 0.9627 - val_top-5-accuracy: 1.0000
# Epoch 93/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3053 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.3415 - val_accuracy: 0.9688 - val_top-5-accuracy: 1.0000
# Epoch 94/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3177 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.5151 - val_accuracy: 0.8882 - val_top-5-accuracy: 1.0000
# Epoch 95/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3048 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.3269 - val_accuracy: 0.9829 - val_top-5-accuracy: 1.0000
# Epoch 96/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3113 - accuracy: 0.9899 - top-5-accuracy: 1.0000 - val_loss: 0.5077 - val_accuracy: 0.8741 - val_top-5-accuracy: 1.0000
# Epoch 97/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3052 - accuracy: 0.9926 - top-5-accuracy: 1.0000 - val_loss: 0.4074 - val_accuracy: 0.9496 - val_top-5-accuracy: 1.0000
# Epoch 98/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3122 - accuracy: 0.9909 - top-5-accuracy: 1.0000 - val_loss: 0.4181 - val_accuracy: 0.9335 - val_top-5-accuracy: 1.0000
# Epoch 99/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3097 - accuracy: 0.9918 - top-5-accuracy: 1.0000 - val_loss: 0.3000 - val_accuracy: 0.9970 - val_top-5-accuracy: 1.0000
# Epoch 100/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3075 - accuracy: 0.9916 - top-5-accuracy: 1.0000 - val_loss: 0.4955 - val_accuracy: 0.9023 - val_top-5-accuracy: 1.0000
# Epoch 101/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3060 - accuracy: 0.9935 - top-5-accuracy: 1.0000 - val_loss: 0.3140 - val_accuracy: 0.9879 - val_top-5-accuracy: 1.0000
# Epoch 102/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3024 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 0.3481 - val_accuracy: 0.9688 - val_top-5-accuracy: 1.0000
# Epoch 103/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3068 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.3145 - val_accuracy: 0.9899 - val_top-5-accuracy: 1.0000
# Epoch 104/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3266 - accuracy: 0.9830 - top-5-accuracy: 1.0000 - val_loss: 0.5199 - val_accuracy: 0.9003 - val_top-5-accuracy: 1.0000
# Epoch 105/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3037 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.4210 - val_accuracy: 0.9386 - val_top-5-accuracy: 1.0000
# Epoch 106/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3051 - accuracy: 0.9933 - top-5-accuracy: 1.0000 - val_loss: 0.4032 - val_accuracy: 0.9446 - val_top-5-accuracy: 1.0000
# Epoch 107/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3115 - accuracy: 0.9909 - top-5-accuracy: 1.0000 - val_loss: 0.4136 - val_accuracy: 0.9406 - val_top-5-accuracy: 1.0000
# Epoch 108/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3098 - accuracy: 0.9904 - top-5-accuracy: 1.0000 - val_loss: 0.3762 - val_accuracy: 0.9658 - val_top-5-accuracy: 1.0000
# Epoch 109/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3074 - accuracy: 0.9928 - top-5-accuracy: 1.0000 - val_loss: 0.3725 - val_accuracy: 0.9567 - val_top-5-accuracy: 1.0000
# Epoch 110/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3016 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.3665 - val_accuracy: 0.9637 - val_top-5-accuracy: 1.0000
# Epoch 111/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3181 - accuracy: 0.9858 - top-5-accuracy: 1.0000 - val_loss: 0.3171 - val_accuracy: 0.9889 - val_top-5-accuracy: 1.0000
# Epoch 112/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3123 - accuracy: 0.9896 - top-5-accuracy: 1.0000 - val_loss: 0.4253 - val_accuracy: 0.9335 - val_top-5-accuracy: 1.0000
# Epoch 113/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3021 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 0.3713 - val_accuracy: 0.9607 - val_top-5-accuracy: 1.0000
# Epoch 114/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3016 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.4899 - val_accuracy: 0.9074 - val_top-5-accuracy: 1.0000
# Epoch 115/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3185 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.3020 - val_accuracy: 0.9940 - val_top-5-accuracy: 1.0000
# Epoch 116/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3148 - accuracy: 0.9899 - top-5-accuracy: 1.0000 - val_loss: 0.3115 - val_accuracy: 0.9909 - val_top-5-accuracy: 1.0000
# Epoch 117/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3027 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 0.4354 - val_accuracy: 0.9275 - val_top-5-accuracy: 1.0000
# Epoch 118/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3118 - accuracy: 0.9898 - top-5-accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.9486 - val_top-5-accuracy: 1.0000
# Epoch 119/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3017 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.3145 - val_accuracy: 0.9859 - val_top-5-accuracy: 1.0000
# Epoch 120/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3077 - accuracy: 0.9916 - top-5-accuracy: 1.0000 - val_loss: 0.7637 - val_accuracy: 0.8177 - val_top-5-accuracy: 1.0000
# Epoch 121/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3250 - accuracy: 0.9832 - top-5-accuracy: 1.0000 - val_loss: 0.3150 - val_accuracy: 0.9919 - val_top-5-accuracy: 1.0000
# Epoch 122/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3042 - accuracy: 0.9945 - top-5-accuracy: 1.0000 - val_loss: 0.3795 - val_accuracy: 0.9466 - val_top-5-accuracy: 1.0000
# Epoch 123/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3057 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 0.4058 - val_accuracy: 0.9376 - val_top-5-accuracy: 1.0000
# Epoch 124/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3020 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.4211 - val_accuracy: 0.9456 - val_top-5-accuracy: 1.0000
# Epoch 125/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3075 - accuracy: 0.9928 - top-5-accuracy: 1.0000 - val_loss: 0.3040 - val_accuracy: 0.9940 - val_top-5-accuracy: 1.0000
# Epoch 126/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2943 - accuracy: 0.9989 - top-5-accuracy: 1.0000 - val_loss: 0.5924 - val_accuracy: 0.8590 - val_top-5-accuracy: 1.0000
# Epoch 127/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3223 - accuracy: 0.9853 - top-5-accuracy: 1.0000 - val_loss: 0.3022 - val_accuracy: 0.9950 - val_top-5-accuracy: 1.0000
# Epoch 128/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3044 - accuracy: 0.9937 - top-5-accuracy: 1.0000 - val_loss: 0.3226 - val_accuracy: 0.9839 - val_top-5-accuracy: 1.0000
# Epoch 129/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3097 - accuracy: 0.9908 - top-5-accuracy: 1.0000 - val_loss: 0.3366 - val_accuracy: 0.9738 - val_top-5-accuracy: 1.0000
# Epoch 130/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3042 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.3170 - val_accuracy: 0.9899 - val_top-5-accuracy: 1.0000
# Epoch 131/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3101 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.3158 - val_accuracy: 0.9849 - val_top-5-accuracy: 1.0000
# Epoch 132/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3045 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 0.3262 - val_accuracy: 0.9839 - val_top-5-accuracy: 1.0000
# Epoch 133/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2990 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 0.2919 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 134/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3006 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 1.1953 - val_accuracy: 0.5519 - val_top-5-accuracy: 1.0000
# Epoch 135/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3150 - accuracy: 0.9887 - top-5-accuracy: 1.0000 - val_loss: 0.3407 - val_accuracy: 0.9809 - val_top-5-accuracy: 1.0000
# Epoch 136/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3219 - accuracy: 0.9847 - top-5-accuracy: 1.0000 - val_loss: 0.3879 - val_accuracy: 0.9527 - val_top-5-accuracy: 1.0000
# Epoch 137/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3094 - accuracy: 0.9909 - top-5-accuracy: 1.0000 - val_loss: 0.3597 - val_accuracy: 0.9567 - val_top-5-accuracy: 1.0000
# Epoch 138/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2966 - accuracy: 0.9980 - top-5-accuracy: 1.0000 - val_loss: 0.3511 - val_accuracy: 0.9718 - val_top-5-accuracy: 1.0000
# Epoch 139/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3078 - accuracy: 0.9927 - top-5-accuracy: 1.0000 - val_loss: 0.4153 - val_accuracy: 0.9335 - val_top-5-accuracy: 1.0000
# Epoch 140/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3016 - accuracy: 0.9959 - top-5-accuracy: 1.0000 - val_loss: 0.3594 - val_accuracy: 0.9718 - val_top-5-accuracy: 1.0000
# Epoch 141/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2936 - accuracy: 0.9994 - top-5-accuracy: 1.0000 - val_loss: 0.3341 - val_accuracy: 0.9778 - val_top-5-accuracy: 1.0000
# Epoch 142/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3156 - accuracy: 0.9878 - top-5-accuracy: 1.0000 - val_loss: 0.4461 - val_accuracy: 0.8963 - val_top-5-accuracy: 1.0000
# Epoch 143/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3085 - accuracy: 0.9926 - top-5-accuracy: 1.0000 - val_loss: 0.4153 - val_accuracy: 0.9406 - val_top-5-accuracy: 1.0000
# Epoch 144/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2981 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.3601 - val_accuracy: 0.9627 - val_top-5-accuracy: 1.0000
# Epoch 145/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3122 - accuracy: 0.9897 - top-5-accuracy: 1.0000 - val_loss: 0.7323 - val_accuracy: 0.8338 - val_top-5-accuracy: 1.0000
# Epoch 146/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3179 - accuracy: 0.9872 - top-5-accuracy: 1.0000 - val_loss: 0.3251 - val_accuracy: 0.9799 - val_top-5-accuracy: 1.0000
# Epoch 147/200
# 279/279 [==============================] - 26s 95ms/step - loss: 0.2964 - accuracy: 0.9982 - top-5-accuracy: 1.0000 - val_loss: 0.3089 - val_accuracy: 0.9899 - val_top-5-accuracy: 1.0000
# Epoch 148/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3014 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.3928 - val_accuracy: 0.9446 - val_top-5-accuracy: 1.0000
# Epoch 149/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3000 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 0.3647 - val_accuracy: 0.9637 - val_top-5-accuracy: 1.0000
# Epoch 150/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3169 - accuracy: 0.9870 - top-5-accuracy: 1.0000 - val_loss: 0.2972 - val_accuracy: 0.9980 - val_top-5-accuracy: 1.0000
# Epoch 151/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3088 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.3718 - val_accuracy: 0.9466 - val_top-5-accuracy: 1.0000
# Epoch 152/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3005 - accuracy: 0.9964 - top-5-accuracy: 1.0000 - val_loss: 0.3478 - val_accuracy: 0.9698 - val_top-5-accuracy: 1.0000
# Epoch 153/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2979 - accuracy: 0.9973 - top-5-accuracy: 1.0000 - val_loss: 0.3561 - val_accuracy: 0.9607 - val_top-5-accuracy: 1.0000
# Epoch 154/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3101 - accuracy: 0.9912 - top-5-accuracy: 1.0000 - val_loss: 0.3268 - val_accuracy: 0.9789 - val_top-5-accuracy: 1.0000
# Epoch 155/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3167 - accuracy: 0.9868 - top-5-accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9899 - val_top-5-accuracy: 1.0000
# Epoch 156/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2987 - accuracy: 0.9973 - top-5-accuracy: 1.0000 - val_loss: 0.5874 - val_accuracy: 0.8560 - val_top-5-accuracy: 1.0000
# Epoch 157/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2985 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.3220 - val_accuracy: 0.9819 - val_top-5-accuracy: 1.0000
# Epoch 158/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3212 - accuracy: 0.9838 - top-5-accuracy: 1.0000 - val_loss: 0.4427 - val_accuracy: 0.9315 - val_top-5-accuracy: 1.0000
# Epoch 159/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3188 - accuracy: 0.9861 - top-5-accuracy: 1.0000 - val_loss: 0.5688 - val_accuracy: 0.8499 - val_top-5-accuracy: 1.0000
# Epoch 160/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2994 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 0.6162 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 161/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2958 - accuracy: 0.9987 - top-5-accuracy: 1.0000 - val_loss: 0.3157 - val_accuracy: 0.9859 - val_top-5-accuracy: 1.0000
# Epoch 162/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3100 - accuracy: 0.9912 - top-5-accuracy: 1.0000 - val_loss: 0.5088 - val_accuracy: 0.9084 - val_top-5-accuracy: 1.0000
# Epoch 163/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3206 - accuracy: 0.9862 - top-5-accuracy: 1.0000 - val_loss: 0.2976 - val_accuracy: 0.9980 - val_top-5-accuracy: 1.0000
# Epoch 164/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3030 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.3762 - val_accuracy: 0.9627 - val_top-5-accuracy: 1.0000
# Epoch 165/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3003 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 0.3029 - val_accuracy: 0.9960 - val_top-5-accuracy: 1.0000
# Epoch 166/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3166 - accuracy: 0.9878 - top-5-accuracy: 1.0000 - val_loss: 0.3036 - val_accuracy: 0.9940 - val_top-5-accuracy: 1.0000
# Epoch 167/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3076 - accuracy: 0.9928 - top-5-accuracy: 1.0000 - val_loss: 0.3647 - val_accuracy: 0.9587 - val_top-5-accuracy: 1.0000
# Epoch 168/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2982 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 0.3455 - val_accuracy: 0.9748 - val_top-5-accuracy: 1.0000
# Epoch 169/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2993 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.3227 - val_accuracy: 0.9819 - val_top-5-accuracy: 1.0000
# Epoch 170/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3114 - accuracy: 0.9916 - top-5-accuracy: 1.0000 - val_loss: 0.5365 - val_accuracy: 0.8822 - val_top-5-accuracy: 1.0000
# Epoch 171/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3019 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 0.5173 - val_accuracy: 0.8832 - val_top-5-accuracy: 1.0000
# Epoch 172/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3046 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 0.3365 - val_accuracy: 0.9738 - val_top-5-accuracy: 1.0000
# Epoch 173/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3153 - accuracy: 0.9892 - top-5-accuracy: 1.0000 - val_loss: 0.3805 - val_accuracy: 0.9517 - val_top-5-accuracy: 1.0000
# Epoch 174/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3095 - accuracy: 0.9915 - top-5-accuracy: 1.0000 - val_loss: 0.3536 - val_accuracy: 0.9617 - val_top-5-accuracy: 1.0000
# Epoch 175/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2998 - accuracy: 0.9970 - top-5-accuracy: 1.0000 - val_loss: 0.3255 - val_accuracy: 0.9809 - val_top-5-accuracy: 1.0000
# Epoch 176/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3084 - accuracy: 0.9918 - top-5-accuracy: 1.0000 - val_loss: 0.3168 - val_accuracy: 0.9859 - val_top-5-accuracy: 1.0000
# Epoch 177/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3014 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 0.3587 - val_accuracy: 0.9597 - val_top-5-accuracy: 1.0000
# Epoch 178/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3056 - accuracy: 0.9933 - top-5-accuracy: 1.0000 - val_loss: 0.4389 - val_accuracy: 0.9275 - val_top-5-accuracy: 1.0000
# Epoch 179/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3027 - accuracy: 0.9945 - top-5-accuracy: 1.0000 - val_loss: 0.3261 - val_accuracy: 0.9799 - val_top-5-accuracy: 1.0000
# Epoch 180/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3150 - accuracy: 0.9889 - top-5-accuracy: 1.0000 - val_loss: 0.3827 - val_accuracy: 0.9517 - val_top-5-accuracy: 1.0000
# Epoch 181/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3062 - accuracy: 0.9926 - top-5-accuracy: 1.0000 - val_loss: 0.3129 - val_accuracy: 0.9889 - val_top-5-accuracy: 1.0000
# Epoch 182/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3005 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 0.7744 - val_accuracy: 0.7976 - val_top-5-accuracy: 1.0000
# Epoch 183/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3091 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 0.3945 - val_accuracy: 0.9507 - val_top-5-accuracy: 1.0000
# Epoch 184/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3019 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 0.5292 - val_accuracy: 0.8812 - val_top-5-accuracy: 1.0000
# Epoch 185/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3026 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 0.4067 - val_accuracy: 0.9416 - val_top-5-accuracy: 1.0000
# Epoch 186/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2958 - accuracy: 0.9985 - top-5-accuracy: 1.0000 - val_loss: 0.4832 - val_accuracy: 0.9003 - val_top-5-accuracy: 1.0000
# Epoch 187/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3146 - accuracy: 0.9900 - top-5-accuracy: 1.0000 - val_loss: 0.4359 - val_accuracy: 0.9184 - val_top-5-accuracy: 1.0000
# Epoch 188/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3082 - accuracy: 0.9916 - top-5-accuracy: 1.0000 - val_loss: 0.3158 - val_accuracy: 0.9869 - val_top-5-accuracy: 1.0000
# Epoch 189/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3006 - accuracy: 0.9957 - top-5-accuracy: 1.0000 - val_loss: 0.3120 - val_accuracy: 0.9899 - val_top-5-accuracy: 1.0000
# Epoch 190/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3029 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 0.3099 - val_accuracy: 0.9909 - val_top-5-accuracy: 1.0000
# Epoch 191/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3164 - accuracy: 0.9864 - top-5-accuracy: 1.0000 - val_loss: 0.4888 - val_accuracy: 0.8973 - val_top-5-accuracy: 1.0000
# Epoch 192/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3142 - accuracy: 0.9889 - top-5-accuracy: 1.0000 - val_loss: 0.3902 - val_accuracy: 0.9486 - val_top-5-accuracy: 1.0000
# Epoch 193/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2986 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 0.3230 - val_accuracy: 0.9849 - val_top-5-accuracy: 1.0000
# Epoch 194/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2969 - accuracy: 0.9978 - top-5-accuracy: 1.0000 - val_loss: 0.5659 - val_accuracy: 0.8731 - val_top-5-accuracy: 1.0000
# Epoch 195/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3110 - accuracy: 0.9908 - top-5-accuracy: 1.0000 - val_loss: 0.5369 - val_accuracy: 0.8721 - val_top-5-accuracy: 1.0000
# Epoch 196/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3110 - accuracy: 0.9908 - top-5-accuracy: 1.0000 - val_loss: 0.3352 - val_accuracy: 0.9789 - val_top-5-accuracy: 1.0000
# Epoch 197/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.2969 - accuracy: 0.9978 - top-5-accuracy: 1.0000 - val_loss: 0.3078 - val_accuracy: 0.9930 - val_top-5-accuracy: 1.0000
# Epoch 198/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3013 - accuracy: 0.9954 - top-5-accuracy: 1.0000 - val_loss: 0.4997 - val_accuracy: 0.9084 - val_top-5-accuracy: 1.0000
# Epoch 199/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3133 - accuracy: 0.9900 - top-5-accuracy: 1.0000 - val_loss: 0.3456 - val_accuracy: 0.9718 - val_top-5-accuracy: 1.0000
# Epoch 200/200
# 279/279 [==============================] - 26s 94ms/step - loss: 0.3041 - accuracy: 0.9937 - top-5-accuracy: 1.0000 - val_loss: 0.3223 - val_accuracy: 0.9839 - val_top-5-accuracy: 1.0000
# 45/45 [==============================] - 1s 32ms/step - loss: 0.3134 - accuracy: 0.9880 - top-5-accuracy: 1.0000
# Test accuracy: 98.8%
# Test top 5 accuracy: 100.0%

# %%
from matplotlib import pyplot as plt
import matplotlib as mpl
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(1)
import matplotlib as mpl
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
plt.grid()
plt.show()

# %%
# p = Augmentor.Pipeline("3D Objects/raw/",output_directory="../New_folder")
# #Step 3 Define the Operations
# p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
# p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
# p.sample(800)

import pathlib
import tensorflow as tf

data_dir = pathlib.Path('./Downloads/Final_Train_Test_thesis2.0/train')

img_height=128
img_width=128


train_ds  = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=32)
# Out:
# Found 9921 files belonging to 3 classes.
# Using 7937 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=32)

normalization_layer = tf.keras.layers.Rescaling(1./255)


import numpy as np
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))


AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 9921 files belonging to 3 classes.
# Using 1984 files for validation.
# 0.016666668 1.0

# %%
train_label = np.concatenate([y for x, y in train_ds], axis=0)
print(train_label.shape)

test_label = np.concatenate([y for x, y in val_ds], axis=0) 
print(test_label.shape)
# Out:
# (7937,)
# (1984,)

# %%
import scipy
# if this works
from scipy.sparse import issparse

# %%
# !pip install scikit-learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
#Confution Matrix and Classification Report
import matplotlib.pyplot as plt
Y_pred = cct_model.predict_generator(val_ds, 700)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm=confusion_matrix(test_label, y_pred)
print(cm)
print('Classification Report')
target_names = ['Flood', 'Flood with Habitation', 'No Flood']
#target_names = ['Normal','Glocoman']
print(classification_report(test_label, y_pred, target_names=target_names))
# Out:
# Requirement already satisfied: scikit-learn in c:\users\20101621\.conda\envs\new_env\lib\site-packages (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (3.1.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# C:\Users\20101621\.conda\envs\new_env\lib\site-packages\keras\engine\training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 700 batches). You may need to use the repeat() function when building your dataset.
# Confusion Matrix
# [[654   0   1]
#  [  2 710   5]
#  [  0   0 612]]
# Classification Report
#                        precision    recall  f1-score   support
#
#                 Flood       1.00      1.00      1.00       655
# Flood with Habitation       1.00      0.99      1.00       717
#              No Flood       0.99      1.00      1.00       612
#
#              accuracy                           1.00      1984
#             macro avg       1.00      1.00      1.00      1984
#          weighted avg       1.00      1.00      1.00      1984

# %%
# !pip install seaborn
import seaborn as sns
sns.set(font_scale=1.0)
ax=sns.heatmap(cm, annot=True, cmap='summer', cbar=False, linewidths=3, linecolor='r', square=True, xticklabels=target_names,yticklabels=target_names,fmt='')
#sns.heatmap(cm, annot=True,annot_kws={"size": 22})
import matplotlib as mpl
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
sns.set(font_scale = 2.0)
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nActual Values')
ax.set_ylabel('Predicted Values ');
# Out:
# Requirement already satisfied: seaborn in c:\users\20101621\.conda\envs\new_env\lib\site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)

# %%
cct_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# data (Sequential)               (None, 128, 128, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# cct_tokenizer (CCTTokenizer)    (None, None, None)   75456       data[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 1024, 128)    0           cct_tokenizer[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 1024, 128)    256         tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# multi_head_attention (MultiHead (None, 1024, 128)    131968      layer_normalization[0][0]
#                                                                  layer_normalization[0][0]
# __________________________________________________________________________________________________
# stochastic_depth (StochasticDep (None, 1024, 128)    0           multi_head_attention[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1024, 128)    0           stochastic_depth[0][0]
#                                                                  tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 1024, 128)    256         add[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1024, 128)    16512       layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024, 128)    0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024, 128)    16512       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024, 128)    0           dense_1[0][0]
# __________________________________________________________________________________________________
# stochastic_depth_1 (StochasticD (None, 1024, 128)    0           dropout_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1024, 128)    0           stochastic_depth_1[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 1024, 128)    256         add_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_1 (MultiHe (None, 1024, 128)    131968      layer_normalization_2[0][0]
#                                                                  layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# stochastic_depth_2 (StochasticD (None, 1024, 128)    0           multi_head_attention_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 1024, 128)    0           stochastic_depth_2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 1024, 128)    256         add_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024, 128)    16512       layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024, 128)    0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024, 128)    16512       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1024, 128)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# stochastic_depth_3 (StochasticD (None, 1024, 128)    0           dropout_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1024, 128)    0           stochastic_depth_3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_4 (LayerNor (None, 1024, 128)    256         add_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1024, 1)      129         layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# tf.nn.softmax (TFOpLambda)      (None, 1024, 1)      0           dense_4[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul (TFOpLambda)   (None, 1, 128)       0           tf.nn.softmax[0][0]
#                                                                  layer_normalization_4[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze (TFOpLambd (None, 128)          0           tf.linalg.matmul[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 3)            387         tf.compat.v1.squeeze[0][0]
# ==================================================================================================
# Total params: 407,236
# Trainable params: 407,236
# Non-trainable params: 0
# __________________________________________________________________________________________________
