# %%
import tensorflow as tf
from tensorflow import keras
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.test.is_built_with_cuda()
print(tf.version.VERSION)
import sys
sys.version
# Out:
# Num GPUs Available:  1
# 2.6.0
# '3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)]'

# %%
# !pip install -U tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in c:\users\20101621\.conda\envs\new_env\lib\site-packages (0.20.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: packaging in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from tensorflow-addons) (23.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)

# %%
# !pip install wheel
# !pip install pandas
# !pip install opencv-python
# !pip install matplotlib
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: wheel in c:\users\20101621\.conda\envs\new_env\lib\site-packages (0.35.1)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# Requirement already satisfied: pandas in c:\users\20101621\.conda\envs\new_env\lib\site-packages (2.0.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# Requirement already satisfied: opencv-python in c:\users\20101621\.conda\envs\new_env\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from opencv-python) (1.23.5)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# Requirement already satisfied: matplotlib in c:\users\20101621\.conda\envs\new_env\lib\site-packages (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)

# %%
train_path = "./Downloads/Final_Train_Test_thesis2.0/train"
test_path = "./Downloads/Final_Train_Test_thesis2.0/test"
x_train=[]  

for folder in os.listdir(train_path):

    sub_path=train_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_train.append(img_arr)

x_test=[]

for folder in os.listdir(test_path):

    sub_path=test_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_test.append(img_arr)

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128, 128),
                                                 batch_size = 500,
                                                 class_mode = 'sparse')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (128, 128),
                                            batch_size = 500,
                                            class_mode = 'sparse')
# Out:
# Found 9921 images belonging to 3 classes.
# Found 1420 images belonging to 3 classes.

# %%
y_train=training_set.classes
y_test=test_set.classes

# %%
NUM_CLASSES = 4
INPUT_SHAPE = (128, 128, 3)


print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
y_train = y_train.reshape((len(y_train), 1))
y_test = y_test.reshape((len(y_test), 1))
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (9921, 128, 128, 3) - y_train shape: (9921,)
# x_test shape: (1420, 128, 128, 3) - y_test shape: (1420,)
# x_train shape: (9921, 128, 128, 3) - y_train shape: (9921, 1)
# x_test shape: (1420, 128, 128, 3) - y_test shape: (1420, 1)

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 500
num_epochs = 200
image_size = 128  # We'll resize input images to this size
patch_size = 16   # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64 
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 128 X 128
# Patch size: 16 X 16
# Patches per image: 64
# Elements per patch: 768

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded
def create_vit_classifier():
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.05)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "Downloads/final_datasets"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.2,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history

# %%
vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 14s 239ms/step - loss: 2.4220 - accuracy: 0.4956 - top-5-accuracy: 1.0000 - val_loss: 1.8463 - val_accuracy: 0.0217 - val_top-5-accuracy: 1.0000
# Epoch 2/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.6769 - accuracy: 0.7030 - top-5-accuracy: 1.0000 - val_loss: 1.6496 - val_accuracy: 0.1819 - val_top-5-accuracy: 1.0000
# Epoch 3/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.5553 - accuracy: 0.7692 - top-5-accuracy: 1.0000 - val_loss: 2.0680 - val_accuracy: 0.1662 - val_top-5-accuracy: 1.0000
# Epoch 4/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.4966 - accuracy: 0.7960 - top-5-accuracy: 1.0000 - val_loss: 1.6327 - val_accuracy: 0.4403 - val_top-5-accuracy: 1.0000
# Epoch 5/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.4147 - accuracy: 0.8308 - top-5-accuracy: 1.0000 - val_loss: 1.5769 - val_accuracy: 0.5048 - val_top-5-accuracy: 1.0000
# Epoch 6/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.3670 - accuracy: 0.8531 - top-5-accuracy: 1.0000 - val_loss: 1.5612 - val_accuracy: 0.5673 - val_top-5-accuracy: 1.0000
# Epoch 7/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.3271 - accuracy: 0.8722 - top-5-accuracy: 1.0000 - val_loss: 1.7233 - val_accuracy: 0.6040 - val_top-5-accuracy: 1.0000
# Epoch 8/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.3189 - accuracy: 0.8756 - top-5-accuracy: 1.0000 - val_loss: 2.1774 - val_accuracy: 0.4171 - val_top-5-accuracy: 1.0000
# Epoch 9/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.3034 - accuracy: 0.8804 - top-5-accuracy: 1.0000 - val_loss: 1.7368 - val_accuracy: 0.5758 - val_top-5-accuracy: 1.0000
# Epoch 10/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.2654 - accuracy: 0.8976 - top-5-accuracy: 1.0000 - val_loss: 1.7457 - val_accuracy: 0.6630 - val_top-5-accuracy: 1.0000
# Epoch 11/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.2446 - accuracy: 0.9037 - top-5-accuracy: 1.0000 - val_loss: 2.0815 - val_accuracy: 0.6479 - val_top-5-accuracy: 1.0000
# Epoch 12/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.2250 - accuracy: 0.9133 - top-5-accuracy: 1.0000 - val_loss: 2.3176 - val_accuracy: 0.6217 - val_top-5-accuracy: 1.0000
# Epoch 13/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.2045 - accuracy: 0.9217 - top-5-accuracy: 1.0000 - val_loss: 2.3598 - val_accuracy: 0.6343 - val_top-5-accuracy: 1.0000
# Epoch 14/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.1942 - accuracy: 0.9257 - top-5-accuracy: 1.0000 - val_loss: 2.4550 - val_accuracy: 0.6267 - val_top-5-accuracy: 1.0000
# Epoch 15/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.1711 - accuracy: 0.9357 - top-5-accuracy: 1.0000 - val_loss: 1.8708 - val_accuracy: 0.7516 - val_top-5-accuracy: 1.0000
# Epoch 16/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.1494 - accuracy: 0.9453 - top-5-accuracy: 1.0000 - val_loss: 2.0100 - val_accuracy: 0.6866 - val_top-5-accuracy: 1.0000
# Epoch 17/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.1261 - accuracy: 0.9511 - top-5-accuracy: 1.0000 - val_loss: 2.0740 - val_accuracy: 0.7416 - val_top-5-accuracy: 1.0000
# Epoch 18/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.1257 - accuracy: 0.9541 - top-5-accuracy: 1.0000 - val_loss: 2.0968 - val_accuracy: 0.7264 - val_top-5-accuracy: 1.0000
# Epoch 19/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.1074 - accuracy: 0.9613 - top-5-accuracy: 1.0000 - val_loss: 2.4619 - val_accuracy: 0.7229 - val_top-5-accuracy: 1.0000
# Epoch 20/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.1044 - accuracy: 0.9607 - top-5-accuracy: 1.0000 - val_loss: 2.8098 - val_accuracy: 0.6927 - val_top-5-accuracy: 1.0000
# Epoch 21/200
# 16/16 [==============================] - 3s 171ms/step - loss: 0.1023 - accuracy: 0.9619 - top-5-accuracy: 1.0000 - val_loss: 2.1733 - val_accuracy: 0.7768 - val_top-5-accuracy: 1.0000
# Epoch 22/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0871 - accuracy: 0.9671 - top-5-accuracy: 1.0000 - val_loss: 2.4828 - val_accuracy: 0.7491 - val_top-5-accuracy: 1.0000
# Epoch 23/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0756 - accuracy: 0.9733 - top-5-accuracy: 1.0000 - val_loss: 2.6251 - val_accuracy: 0.7340 - val_top-5-accuracy: 1.0000
# Epoch 24/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0731 - accuracy: 0.9715 - top-5-accuracy: 1.0000 - val_loss: 2.3581 - val_accuracy: 0.7678 - val_top-5-accuracy: 1.0000
# Epoch 25/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0817 - accuracy: 0.9733 - top-5-accuracy: 1.0000 - val_loss: 2.1578 - val_accuracy: 0.7622 - val_top-5-accuracy: 1.0000
# Epoch 26/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0650 - accuracy: 0.9758 - top-5-accuracy: 1.0000 - val_loss: 2.3804 - val_accuracy: 0.7531 - val_top-5-accuracy: 1.0000
# Epoch 27/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0605 - accuracy: 0.9795 - top-5-accuracy: 1.0000 - val_loss: 2.5644 - val_accuracy: 0.7461 - val_top-5-accuracy: 1.0000
# Epoch 28/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0528 - accuracy: 0.9803 - top-5-accuracy: 1.0000 - val_loss: 2.4143 - val_accuracy: 0.7683 - val_top-5-accuracy: 1.0000
# Epoch 29/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0438 - accuracy: 0.9851 - top-5-accuracy: 1.0000 - val_loss: 2.9195 - val_accuracy: 0.7073 - val_top-5-accuracy: 1.0000
# Epoch 30/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0470 - accuracy: 0.9850 - top-5-accuracy: 1.0000 - val_loss: 2.8425 - val_accuracy: 0.7219 - val_top-5-accuracy: 1.0000
# Epoch 31/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0499 - accuracy: 0.9807 - top-5-accuracy: 1.0000 - val_loss: 2.7143 - val_accuracy: 0.7773 - val_top-5-accuracy: 1.0000
# Epoch 32/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0528 - accuracy: 0.9807 - top-5-accuracy: 1.0000 - val_loss: 2.5620 - val_accuracy: 0.7491 - val_top-5-accuracy: 1.0000
# Epoch 33/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0446 - accuracy: 0.9850 - top-5-accuracy: 1.0000 - val_loss: 3.0044 - val_accuracy: 0.7355 - val_top-5-accuracy: 1.0000
# Epoch 34/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0468 - accuracy: 0.9844 - top-5-accuracy: 1.0000 - val_loss: 2.8612 - val_accuracy: 0.7083 - val_top-5-accuracy: 1.0000
# Epoch 35/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0439 - accuracy: 0.9855 - top-5-accuracy: 1.0000 - val_loss: 2.8687 - val_accuracy: 0.7229 - val_top-5-accuracy: 1.0000
# Epoch 36/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0342 - accuracy: 0.9869 - top-5-accuracy: 1.0000 - val_loss: 2.6494 - val_accuracy: 0.7612 - val_top-5-accuracy: 1.0000
# Epoch 37/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0397 - accuracy: 0.9868 - top-5-accuracy: 1.0000 - val_loss: 3.0015 - val_accuracy: 0.7592 - val_top-5-accuracy: 1.0000
# Epoch 38/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0317 - accuracy: 0.9885 - top-5-accuracy: 1.0000 - val_loss: 2.6598 - val_accuracy: 0.7340 - val_top-5-accuracy: 1.0000
# Epoch 39/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0322 - accuracy: 0.9882 - top-5-accuracy: 1.0000 - val_loss: 2.6846 - val_accuracy: 0.7728 - val_top-5-accuracy: 1.0000
# Epoch 40/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0376 - accuracy: 0.9865 - top-5-accuracy: 1.0000 - val_loss: 3.0715 - val_accuracy: 0.6866 - val_top-5-accuracy: 1.0000
# Epoch 41/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0427 - accuracy: 0.9851 - top-5-accuracy: 1.0000 - val_loss: 2.3745 - val_accuracy: 0.7809 - val_top-5-accuracy: 1.0000
# Epoch 42/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0393 - accuracy: 0.9853 - top-5-accuracy: 1.0000 - val_loss: 2.6943 - val_accuracy: 0.7411 - val_top-5-accuracy: 1.0000
# Epoch 43/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0403 - accuracy: 0.9879 - top-5-accuracy: 1.0000 - val_loss: 2.5724 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 44/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0308 - accuracy: 0.9898 - top-5-accuracy: 1.0000 - val_loss: 3.2272 - val_accuracy: 0.7043 - val_top-5-accuracy: 1.0000
# Epoch 45/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0315 - accuracy: 0.9893 - top-5-accuracy: 1.0000 - val_loss: 2.9552 - val_accuracy: 0.7083 - val_top-5-accuracy: 1.0000
# Epoch 46/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0334 - accuracy: 0.9888 - top-5-accuracy: 1.0000 - val_loss: 2.8548 - val_accuracy: 0.7466 - val_top-5-accuracy: 1.0000
# Epoch 47/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0348 - accuracy: 0.9884 - top-5-accuracy: 1.0000 - val_loss: 3.1543 - val_accuracy: 0.7008 - val_top-5-accuracy: 1.0000
# Epoch 48/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0297 - accuracy: 0.9894 - top-5-accuracy: 1.0000 - val_loss: 2.6749 - val_accuracy: 0.7537 - val_top-5-accuracy: 1.0000
# Epoch 49/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0283 - accuracy: 0.9909 - top-5-accuracy: 1.0000 - val_loss: 3.0704 - val_accuracy: 0.7189 - val_top-5-accuracy: 1.0000
# Epoch 50/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0192 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 2.8057 - val_accuracy: 0.7728 - val_top-5-accuracy: 1.0000
# Epoch 51/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0266 - accuracy: 0.9918 - top-5-accuracy: 1.0000 - val_loss: 2.8035 - val_accuracy: 0.7783 - val_top-5-accuracy: 1.0000
# Epoch 52/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0315 - accuracy: 0.9899 - top-5-accuracy: 1.0000 - val_loss: 3.1715 - val_accuracy: 0.7436 - val_top-5-accuracy: 1.0000
# Epoch 53/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0272 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 3.0950 - val_accuracy: 0.7567 - val_top-5-accuracy: 1.0000
# Epoch 54/200
# 16/16 [==============================] - 3s 172ms/step - loss: 0.0218 - accuracy: 0.9931 - top-5-accuracy: 1.0000 - val_loss: 3.0223 - val_accuracy: 0.6942 - val_top-5-accuracy: 1.0000
# Epoch 55/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0180 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 2.7983 - val_accuracy: 0.7763 - val_top-5-accuracy: 1.0000
# Epoch 56/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0188 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 3.4108 - val_accuracy: 0.6831 - val_top-5-accuracy: 1.0000
# Epoch 57/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0280 - accuracy: 0.9912 - top-5-accuracy: 1.0000 - val_loss: 3.1941 - val_accuracy: 0.7370 - val_top-5-accuracy: 1.0000
# Epoch 58/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0312 - accuracy: 0.9892 - top-5-accuracy: 1.0000 - val_loss: 3.1534 - val_accuracy: 0.7098 - val_top-5-accuracy: 1.0000
# Epoch 59/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0272 - accuracy: 0.9899 - top-5-accuracy: 1.0000 - val_loss: 3.1147 - val_accuracy: 0.7300 - val_top-5-accuracy: 1.0000
# Epoch 60/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0287 - accuracy: 0.9895 - top-5-accuracy: 1.0000 - val_loss: 3.2159 - val_accuracy: 0.7270 - val_top-5-accuracy: 1.0000
# Epoch 61/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0269 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 3.1088 - val_accuracy: 0.7708 - val_top-5-accuracy: 1.0000
# Epoch 62/200
# 16/16 [==============================] - 3s 172ms/step - loss: 0.0303 - accuracy: 0.9898 - top-5-accuracy: 1.0000 - val_loss: 3.3607 - val_accuracy: 0.7355 - val_top-5-accuracy: 1.0000
# Epoch 63/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0238 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 2.9670 - val_accuracy: 0.7456 - val_top-5-accuracy: 1.0000
# Epoch 64/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0155 - accuracy: 0.9955 - top-5-accuracy: 1.0000 - val_loss: 3.1203 - val_accuracy: 0.7511 - val_top-5-accuracy: 1.0000
# Epoch 65/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0178 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 3.1506 - val_accuracy: 0.7516 - val_top-5-accuracy: 1.0000
# Epoch 66/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0219 - accuracy: 0.9931 - top-5-accuracy: 1.0000 - val_loss: 3.4076 - val_accuracy: 0.7083 - val_top-5-accuracy: 1.0000
# Epoch 67/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0225 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 3.5017 - val_accuracy: 0.6882 - val_top-5-accuracy: 1.0000
# Epoch 68/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0163 - accuracy: 0.9945 - top-5-accuracy: 1.0000 - val_loss: 3.2678 - val_accuracy: 0.7239 - val_top-5-accuracy: 1.0000
# Epoch 69/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0165 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 3.3031 - val_accuracy: 0.7526 - val_top-5-accuracy: 1.0000
# Epoch 70/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0111 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 2.9642 - val_accuracy: 0.7763 - val_top-5-accuracy: 1.0000
# Epoch 71/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0131 - accuracy: 0.9947 - top-5-accuracy: 1.0000 - val_loss: 2.9838 - val_accuracy: 0.7501 - val_top-5-accuracy: 1.0000
# Epoch 72/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0136 - accuracy: 0.9947 - top-5-accuracy: 1.0000 - val_loss: 3.2241 - val_accuracy: 0.7229 - val_top-5-accuracy: 1.0000
# Epoch 73/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0128 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 3.7455 - val_accuracy: 0.7164 - val_top-5-accuracy: 1.0000
# Epoch 74/200
# 16/16 [==============================] - 3s 171ms/step - loss: 0.0119 - accuracy: 0.9955 - top-5-accuracy: 1.0000 - val_loss: 3.3721 - val_accuracy: 0.7788 - val_top-5-accuracy: 1.0000
# Epoch 75/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0156 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 3.4163 - val_accuracy: 0.7330 - val_top-5-accuracy: 1.0000
# Epoch 76/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0175 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 3.8852 - val_accuracy: 0.7123 - val_top-5-accuracy: 1.0000
# Epoch 77/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0242 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 2.8566 - val_accuracy: 0.7718 - val_top-5-accuracy: 1.0000
# Epoch 78/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0216 - accuracy: 0.9914 - top-5-accuracy: 1.0000 - val_loss: 3.5875 - val_accuracy: 0.6650 - val_top-5-accuracy: 1.0000
# Epoch 79/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0305 - accuracy: 0.9895 - top-5-accuracy: 1.0000 - val_loss: 2.8199 - val_accuracy: 0.7275 - val_top-5-accuracy: 1.0000
# Epoch 80/200
# 16/16 [==============================] - 3s 171ms/step - loss: 0.0206 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 3.7226 - val_accuracy: 0.7365 - val_top-5-accuracy: 1.0000
# Epoch 81/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0192 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 2.9033 - val_accuracy: 0.7562 - val_top-5-accuracy: 1.0000
# Epoch 82/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0134 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.6059 - val_accuracy: 0.6746 - val_top-5-accuracy: 1.0000
# Epoch 83/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0169 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 2.8421 - val_accuracy: 0.7708 - val_top-5-accuracy: 1.0000
# Epoch 84/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0157 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 3.0354 - val_accuracy: 0.7466 - val_top-5-accuracy: 1.0000
# Epoch 85/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0134 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 3.4827 - val_accuracy: 0.6957 - val_top-5-accuracy: 1.0000
# Epoch 86/200
# 16/16 [==============================] - 3s 171ms/step - loss: 0.0111 - accuracy: 0.9962 - top-5-accuracy: 1.0000 - val_loss: 3.4664 - val_accuracy: 0.6967 - val_top-5-accuracy: 1.0000
# Epoch 87/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0179 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 3.2122 - val_accuracy: 0.7285 - val_top-5-accuracy: 1.0000
# Epoch 88/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0144 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 2.9286 - val_accuracy: 0.7874 - val_top-5-accuracy: 1.0000
# Epoch 89/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0158 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 2.9582 - val_accuracy: 0.7980 - val_top-5-accuracy: 1.0000
# Epoch 90/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0185 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 2.6251 - val_accuracy: 0.7829 - val_top-5-accuracy: 1.0000
# Epoch 91/200
# 16/16 [==============================] - 3s 178ms/step - loss: 0.0137 - accuracy: 0.9958 - top-5-accuracy: 1.0000 - val_loss: 3.2645 - val_accuracy: 0.7345 - val_top-5-accuracy: 1.0000
# Epoch 92/200
# 16/16 [==============================] - 3s 177ms/step - loss: 0.0171 - accuracy: 0.9947 - top-5-accuracy: 1.0000 - val_loss: 3.0602 - val_accuracy: 0.7134 - val_top-5-accuracy: 1.0000
# Epoch 93/200
# 16/16 [==============================] - 3s 179ms/step - loss: 0.0173 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 2.9541 - val_accuracy: 0.7728 - val_top-5-accuracy: 1.0000
# Epoch 94/200
# 16/16 [==============================] - 3s 174ms/step - loss: 0.0260 - accuracy: 0.9905 - top-5-accuracy: 1.0000 - val_loss: 3.8818 - val_accuracy: 0.6524 - val_top-5-accuracy: 1.0000
# Epoch 95/200
# 16/16 [==============================] - 3s 174ms/step - loss: 0.0195 - accuracy: 0.9937 - top-5-accuracy: 1.0000 - val_loss: 3.6009 - val_accuracy: 0.7350 - val_top-5-accuracy: 1.0000
# Epoch 96/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0234 - accuracy: 0.9921 - top-5-accuracy: 1.0000 - val_loss: 3.5281 - val_accuracy: 0.7365 - val_top-5-accuracy: 1.0000
# Epoch 97/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0183 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 3.2439 - val_accuracy: 0.7003 - val_top-5-accuracy: 1.0000
# Epoch 98/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0149 - accuracy: 0.9947 - top-5-accuracy: 1.0000 - val_loss: 3.8471 - val_accuracy: 0.6997 - val_top-5-accuracy: 1.0000
# Epoch 99/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0148 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 3.9294 - val_accuracy: 0.7028 - val_top-5-accuracy: 1.0000
# Epoch 100/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0089 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 3.3088 - val_accuracy: 0.7698 - val_top-5-accuracy: 1.0000
# Epoch 101/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0177 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 3.1648 - val_accuracy: 0.7506 - val_top-5-accuracy: 1.0000
# Epoch 102/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0157 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.9056 - val_accuracy: 0.6962 - val_top-5-accuracy: 1.0000
# Epoch 103/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0161 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 3.4011 - val_accuracy: 0.7461 - val_top-5-accuracy: 1.0000
# Epoch 104/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0172 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 3.2437 - val_accuracy: 0.7315 - val_top-5-accuracy: 1.0000
# Epoch 105/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0178 - accuracy: 0.9937 - top-5-accuracy: 1.0000 - val_loss: 3.1754 - val_accuracy: 0.7622 - val_top-5-accuracy: 1.0000
# Epoch 106/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0167 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 3.2868 - val_accuracy: 0.7894 - val_top-5-accuracy: 1.0000
# Epoch 107/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0197 - accuracy: 0.9922 - top-5-accuracy: 1.0000 - val_loss: 4.1135 - val_accuracy: 0.6413 - val_top-5-accuracy: 1.0000
# Epoch 108/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0131 - accuracy: 0.9947 - top-5-accuracy: 1.0000 - val_loss: 3.3851 - val_accuracy: 0.7406 - val_top-5-accuracy: 1.0000
# Epoch 109/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0137 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.4393 - val_accuracy: 0.7516 - val_top-5-accuracy: 1.0000
# Epoch 110/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0103 - accuracy: 0.9966 - top-5-accuracy: 1.0000 - val_loss: 3.4704 - val_accuracy: 0.7401 - val_top-5-accuracy: 1.0000
# Epoch 111/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0124 - accuracy: 0.9958 - top-5-accuracy: 1.0000 - val_loss: 3.0369 - val_accuracy: 0.7647 - val_top-5-accuracy: 1.0000
# Epoch 112/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0064 - accuracy: 0.9975 - top-5-accuracy: 1.0000 - val_loss: 3.3691 - val_accuracy: 0.7577 - val_top-5-accuracy: 1.0000
# Epoch 113/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0097 - accuracy: 0.9966 - top-5-accuracy: 1.0000 - val_loss: 3.4416 - val_accuracy: 0.7149 - val_top-5-accuracy: 1.0000
# Epoch 114/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0212 - accuracy: 0.9937 - top-5-accuracy: 1.0000 - val_loss: 4.1031 - val_accuracy: 0.6972 - val_top-5-accuracy: 1.0000
# Epoch 115/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0127 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 2.9060 - val_accuracy: 0.7451 - val_top-5-accuracy: 1.0000
# Epoch 116/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0192 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 3.3483 - val_accuracy: 0.7184 - val_top-5-accuracy: 1.0000
# Epoch 117/200
# 16/16 [==============================] - 3s 164ms/step - loss: 0.0137 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 3.3714 - val_accuracy: 0.7597 - val_top-5-accuracy: 1.0000
# Epoch 118/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0152 - accuracy: 0.9947 - top-5-accuracy: 1.0000 - val_loss: 4.3301 - val_accuracy: 0.6161 - val_top-5-accuracy: 1.0000
# Epoch 119/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0313 - accuracy: 0.9895 - top-5-accuracy: 1.0000 - val_loss: 3.6521 - val_accuracy: 0.7073 - val_top-5-accuracy: 1.0000
# Epoch 120/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0266 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 2.9794 - val_accuracy: 0.7521 - val_top-5-accuracy: 1.0000
# Epoch 121/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0149 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.3766 - val_accuracy: 0.7310 - val_top-5-accuracy: 1.0000
# Epoch 122/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0085 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 2.5588 - val_accuracy: 0.8060 - val_top-5-accuracy: 1.0000
# Epoch 123/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0099 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.2548 - val_accuracy: 0.7567 - val_top-5-accuracy: 1.0000
# Epoch 124/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0061 - accuracy: 0.9975 - top-5-accuracy: 1.0000 - val_loss: 3.7461 - val_accuracy: 0.6811 - val_top-5-accuracy: 1.0000
# Epoch 125/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0102 - accuracy: 0.9974 - top-5-accuracy: 1.0000 - val_loss: 3.5965 - val_accuracy: 0.7239 - val_top-5-accuracy: 1.0000
# Epoch 126/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0098 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.3200 - val_accuracy: 0.7431 - val_top-5-accuracy: 1.0000
# Epoch 127/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0075 - accuracy: 0.9979 - top-5-accuracy: 1.0000 - val_loss: 3.2793 - val_accuracy: 0.6897 - val_top-5-accuracy: 1.0000
# Epoch 128/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0108 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 3.1661 - val_accuracy: 0.7728 - val_top-5-accuracy: 1.0000
# Epoch 129/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0148 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 3.3271 - val_accuracy: 0.7043 - val_top-5-accuracy: 1.0000
# Epoch 130/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0067 - accuracy: 0.9982 - top-5-accuracy: 1.0000 - val_loss: 3.0395 - val_accuracy: 0.7244 - val_top-5-accuracy: 1.0000
# Epoch 131/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0068 - accuracy: 0.9980 - top-5-accuracy: 1.0000 - val_loss: 3.0803 - val_accuracy: 0.7209 - val_top-5-accuracy: 1.0000
# Epoch 132/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0089 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 3.9753 - val_accuracy: 0.7108 - val_top-5-accuracy: 1.0000
# Epoch 133/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0110 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 3.2401 - val_accuracy: 0.7194 - val_top-5-accuracy: 1.0000
# Epoch 134/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0102 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 3.3172 - val_accuracy: 0.7280 - val_top-5-accuracy: 1.0000
# Epoch 135/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0105 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 3.3140 - val_accuracy: 0.7879 - val_top-5-accuracy: 1.0000
# Epoch 136/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0162 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.4537 - val_accuracy: 0.7013 - val_top-5-accuracy: 1.0000
# Epoch 137/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0161 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 2.8469 - val_accuracy: 0.7738 - val_top-5-accuracy: 1.0000
# Epoch 138/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0138 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 3.5105 - val_accuracy: 0.7486 - val_top-5-accuracy: 1.0000
# Epoch 139/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0176 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 3.0200 - val_accuracy: 0.7567 - val_top-5-accuracy: 1.0000
# Epoch 140/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0102 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 3.3749 - val_accuracy: 0.7189 - val_top-5-accuracy: 1.0000
# Epoch 141/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0104 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.0877 - val_accuracy: 0.7446 - val_top-5-accuracy: 1.0000
# Epoch 142/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0049 - accuracy: 0.9984 - top-5-accuracy: 1.0000 - val_loss: 3.7346 - val_accuracy: 0.6972 - val_top-5-accuracy: 1.0000
# Epoch 143/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0046 - accuracy: 0.9984 - top-5-accuracy: 1.0000 - val_loss: 3.8167 - val_accuracy: 0.7461 - val_top-5-accuracy: 1.0000
# Epoch 144/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0079 - accuracy: 0.9976 - top-5-accuracy: 1.0000 - val_loss: 4.4158 - val_accuracy: 0.6816 - val_top-5-accuracy: 1.0000
# Epoch 145/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0093 - accuracy: 0.9970 - top-5-accuracy: 1.0000 - val_loss: 3.7329 - val_accuracy: 0.7637 - val_top-5-accuracy: 1.0000
# Epoch 146/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0080 - accuracy: 0.9980 - top-5-accuracy: 1.0000 - val_loss: 3.5694 - val_accuracy: 0.7365 - val_top-5-accuracy: 1.0000
# Epoch 147/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0129 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 3.2561 - val_accuracy: 0.7421 - val_top-5-accuracy: 1.0000
# Epoch 148/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0139 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 4.1381 - val_accuracy: 0.6484 - val_top-5-accuracy: 1.0000
# Epoch 149/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0119 - accuracy: 0.9955 - top-5-accuracy: 1.0000 - val_loss: 3.2697 - val_accuracy: 0.7375 - val_top-5-accuracy: 1.0000
# Epoch 150/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0147 - accuracy: 0.9955 - top-5-accuracy: 1.0000 - val_loss: 3.5344 - val_accuracy: 0.7637 - val_top-5-accuracy: 1.0000
# Epoch 151/200
# 16/16 [==============================] - 3s 164ms/step - loss: 0.0130 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 3.5849 - val_accuracy: 0.7214 - val_top-5-accuracy: 1.0000
# Epoch 152/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0084 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 3.0860 - val_accuracy: 0.7466 - val_top-5-accuracy: 1.0000
# Epoch 153/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0063 - accuracy: 0.9977 - top-5-accuracy: 1.0000 - val_loss: 4.0611 - val_accuracy: 0.7078 - val_top-5-accuracy: 1.0000
# Epoch 154/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0107 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.9025 - val_accuracy: 0.7063 - val_top-5-accuracy: 1.0000
# Epoch 155/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0097 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 3.9415 - val_accuracy: 0.7169 - val_top-5-accuracy: 1.0000
# Epoch 156/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0094 - accuracy: 0.9970 - top-5-accuracy: 1.0000 - val_loss: 3.4680 - val_accuracy: 0.7526 - val_top-5-accuracy: 1.0000
# Epoch 157/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0118 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 3.7829 - val_accuracy: 0.7088 - val_top-5-accuracy: 1.0000
# Epoch 158/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0093 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 3.9372 - val_accuracy: 0.7330 - val_top-5-accuracy: 1.0000
# Epoch 159/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0094 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 3.4935 - val_accuracy: 0.7542 - val_top-5-accuracy: 1.0000
# Epoch 160/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0109 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.9683 - val_accuracy: 0.7068 - val_top-5-accuracy: 1.0000
# Epoch 161/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0099 - accuracy: 0.9966 - top-5-accuracy: 1.0000 - val_loss: 3.9436 - val_accuracy: 0.7310 - val_top-5-accuracy: 1.0000
# Epoch 162/200
# 16/16 [==============================] - 3s 164ms/step - loss: 0.0102 - accuracy: 0.9970 - top-5-accuracy: 1.0000 - val_loss: 3.8832 - val_accuracy: 0.7063 - val_top-5-accuracy: 1.0000
# Epoch 163/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0089 - accuracy: 0.9966 - top-5-accuracy: 1.0000 - val_loss: 4.1372 - val_accuracy: 0.7259 - val_top-5-accuracy: 1.0000
# Epoch 164/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0052 - accuracy: 0.9982 - top-5-accuracy: 1.0000 - val_loss: 4.4081 - val_accuracy: 0.6846 - val_top-5-accuracy: 1.0000
# Epoch 165/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0103 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 4.3956 - val_accuracy: 0.7033 - val_top-5-accuracy: 1.0000
# Epoch 166/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0118 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.5462 - val_accuracy: 0.7486 - val_top-5-accuracy: 1.0000
# Epoch 167/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0108 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.6292 - val_accuracy: 0.6932 - val_top-5-accuracy: 1.0000
# Epoch 168/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0090 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 3.4897 - val_accuracy: 0.7481 - val_top-5-accuracy: 1.0000
# Epoch 169/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0073 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 3.4867 - val_accuracy: 0.7965 - val_top-5-accuracy: 1.0000
# Epoch 170/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0112 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 3.6942 - val_accuracy: 0.7330 - val_top-5-accuracy: 1.0000
# Epoch 171/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0131 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 3.7590 - val_accuracy: 0.6967 - val_top-5-accuracy: 1.0000
# Epoch 172/200
# 16/16 [==============================] - 3s 164ms/step - loss: 0.0106 - accuracy: 0.9962 - top-5-accuracy: 1.0000 - val_loss: 3.5869 - val_accuracy: 0.7063 - val_top-5-accuracy: 1.0000
# Epoch 173/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0094 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 3.8156 - val_accuracy: 0.7370 - val_top-5-accuracy: 1.0000
# Epoch 174/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0105 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 3.4778 - val_accuracy: 0.7622 - val_top-5-accuracy: 1.0000
# Epoch 175/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0111 - accuracy: 0.9974 - top-5-accuracy: 1.0000 - val_loss: 4.4115 - val_accuracy: 0.7093 - val_top-5-accuracy: 1.0000
# Epoch 176/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0169 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 3.3232 - val_accuracy: 0.7204 - val_top-5-accuracy: 1.0000
# Epoch 177/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0162 - accuracy: 0.9947 - top-5-accuracy: 1.0000 - val_loss: 2.8822 - val_accuracy: 0.7370 - val_top-5-accuracy: 1.0000
# Epoch 178/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0100 - accuracy: 0.9966 - top-5-accuracy: 1.0000 - val_loss: 3.0869 - val_accuracy: 0.7401 - val_top-5-accuracy: 1.0000
# Epoch 179/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0111 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 3.0881 - val_accuracy: 0.7914 - val_top-5-accuracy: 1.0000
# Epoch 180/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0094 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 4.0351 - val_accuracy: 0.7305 - val_top-5-accuracy: 1.0000
# Epoch 181/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0130 - accuracy: 0.9962 - top-5-accuracy: 1.0000 - val_loss: 3.7810 - val_accuracy: 0.7078 - val_top-5-accuracy: 1.0000
# Epoch 182/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0183 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 2.6585 - val_accuracy: 0.7345 - val_top-5-accuracy: 1.0000
# Epoch 183/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0122 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 3.3665 - val_accuracy: 0.7406 - val_top-5-accuracy: 1.0000
# Epoch 184/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0084 - accuracy: 0.9974 - top-5-accuracy: 1.0000 - val_loss: 3.2419 - val_accuracy: 0.7662 - val_top-5-accuracy: 1.0000
# Epoch 185/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0088 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.3169 - val_accuracy: 0.7023 - val_top-5-accuracy: 1.0000
# Epoch 186/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0097 - accuracy: 0.9970 - top-5-accuracy: 1.0000 - val_loss: 3.4997 - val_accuracy: 0.7416 - val_top-5-accuracy: 1.0000
# Epoch 187/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0128 - accuracy: 0.9955 - top-5-accuracy: 1.0000 - val_loss: 3.7196 - val_accuracy: 0.6514 - val_top-5-accuracy: 1.0000
# Epoch 188/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0155 - accuracy: 0.9947 - top-5-accuracy: 1.0000 - val_loss: 3.5004 - val_accuracy: 0.7627 - val_top-5-accuracy: 1.0000
# Epoch 189/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0093 - accuracy: 0.9970 - top-5-accuracy: 1.0000 - val_loss: 3.7068 - val_accuracy: 0.6620 - val_top-5-accuracy: 1.0000
# Epoch 190/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0106 - accuracy: 0.9966 - top-5-accuracy: 1.0000 - val_loss: 3.7126 - val_accuracy: 0.7083 - val_top-5-accuracy: 1.0000
# Epoch 191/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0098 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.6014 - val_accuracy: 0.6736 - val_top-5-accuracy: 1.0000
# Epoch 192/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0103 - accuracy: 0.9962 - top-5-accuracy: 1.0000 - val_loss: 4.3262 - val_accuracy: 0.6907 - val_top-5-accuracy: 1.0000
# Epoch 193/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0187 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 2.7595 - val_accuracy: 0.7698 - val_top-5-accuracy: 1.0000
# Epoch 194/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0146 - accuracy: 0.9962 - top-5-accuracy: 1.0000 - val_loss: 2.9435 - val_accuracy: 0.7375 - val_top-5-accuracy: 1.0000
# Epoch 195/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0104 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 3.1657 - val_accuracy: 0.7531 - val_top-5-accuracy: 1.0000
# Epoch 196/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0065 - accuracy: 0.9980 - top-5-accuracy: 1.0000 - val_loss: 3.6559 - val_accuracy: 0.7295 - val_top-5-accuracy: 1.0000
# Epoch 197/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0044 - accuracy: 0.9985 - top-5-accuracy: 1.0000 - val_loss: 3.4046 - val_accuracy: 0.7592 - val_top-5-accuracy: 1.0000
# Epoch 198/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0057 - accuracy: 0.9985 - top-5-accuracy: 1.0000 - val_loss: 3.3759 - val_accuracy: 0.7567 - val_top-5-accuracy: 1.0000
# Epoch 199/200
# 16/16 [==============================] - 3s 164ms/step - loss: 0.0123 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 3.3011 - val_accuracy: 0.7078 - val_top-5-accuracy: 1.0000
# Epoch 200/200
# 16/16 [==============================] - 3s 165ms/step - loss: 0.0133 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.7271 - val_accuracy: 0.7043 - val_top-5-accuracy: 1.0000
# 45/45 [==============================] - 1s 17ms/step - loss: 0.4278 - accuracy: 0.9563 - top-5-accuracy: 1.0000
# Test accuracy: 95.63%
# Test top 5 accuracy: 100.0%

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

# %%
# p = Augmentor.Pipeline("3D Objects/raw/",output_directory="../New_folder")
# #Step 3 Define the Operations
# p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
# p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
# p.sample(800)

import pathlib
import tensorflow as tf

data_dir = pathlib.Path('./Downloads/Final_Train_Test_thesis2.0/train')

img_height=128
img_width=128


train_ds  = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=500)
# Out:
# Found 9921 files belonging to 3 classes.
# Using 7937 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=32)

normalization_layer = tf.keras.layers.Rescaling(1./255)


import numpy as np
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))


AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 9921 files belonging to 3 classes.
# Using 1984 files for validation.
# 0.004901961 1.0

# %%
train_label = np.concatenate([y for x, y in train_ds], axis=0)
print(train_label.shape)

test_label = np.concatenate([y for x, y in val_ds], axis=0) 
print(test_label.shape)
# Out:
# (7937,)
# (1984,)

# %%
import scipy
# if this works
from scipy.sparse import issparse

# %%
# !pip install scikit-learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
#Confution Matrix and Classification Report
import matplotlib.pyplot as plt
Y_pred = vit_classifier.predict_generator(val_ds, 700)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm=confusion_matrix(test_label, y_pred)
print(cm)
print('Classification Report')
target_names = ['Flood', 'Flood_with_habitation', 'No_Flood']
#target_names = ['Normal','Glocoman']
print(classification_report(test_label, y_pred, target_names=target_names))
# Out:
# Requirement already satisfied: scikit-learn in c:\users\20101621\.conda\envs\new_env\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (3.1.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# C:\Users\20101621\.conda\envs\new_env\lib\site-packages\keras\engine\training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 700 batches). You may need to use the repeat() function when building your dataset.
# Confusion Matrix
# [[652   1   2]
#  [  0 717   0]
#  [ 57  19 536]]
# Classification Report
#                        precision    recall  f1-score   support
#
#                 Flood       0.92      1.00      0.96       655
# Flood_with_habitation       0.97      1.00      0.99       717
#              No_Flood       1.00      0.88      0.93       612
#
#              accuracy                           0.96      1984
#             macro avg       0.96      0.96      0.96      1984
#          weighted avg       0.96      0.96      0.96      1984

# %%
# !pip install seaborn
import seaborn as sns
sns.set(font_scale=1.0)
ax=sns.heatmap(cm, annot=True, cmap='summer', cbar=False, linewidths=3, linecolor='r', square=True, xticklabels=target_names,yticklabels=target_names,fmt='')
#sns.heatmap(cm, annot=True,annot_kws={"size": 22})
sns.set(font_scale = 2.0)
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nActual Values')
ax.set_ylabel('Predicted Values ');
# Out:
# Requirement already satisfied: seaborn in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\19101022.bracu\.conda\envs\new_env_4_8\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
