# %%
import tensorflow as tf
from tensorflow import keras
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
tf.test.is_built_with_cuda()
print(tf.version.VERSION)
import sys
sys.version
# Out:
# Num GPUs Available:  1
# 2.6.0
# '3.9.16 (main, Mar  8 2023, 10:39:24) [MSC v.1916 64 bit (AMD64)]'

# %%
# !pip install -U tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in c:\users\20101621\.conda\envs\new_env\lib\site-packages (0.20.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: packaging in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from tensorflow-addons) (23.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)

# %%
# !pip install wheel
# !pip install pandas
# !pip install opencv-python
# !pip install matplotlib
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: wheel in c:\users\20101621\.conda\envs\new_env\lib\site-packages (0.35.1)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# Requirement already satisfied: pandas in c:\users\20101621\.conda\envs\new_env\lib\site-packages (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# Requirement already satisfied: opencv-python in c:\users\20101621\.conda\envs\new_env\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from opencv-python) (1.23.5)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# Requirement already satisfied: matplotlib in c:\users\20101621\.conda\envs\new_env\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: numpy>=1.20 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)

# %%
train_path = "./Downloads/Final_Train_Test_thesis2.0/train"
test_path = "./Downloads/Final_Train_Test_thesis2.0/test"
x_train=[]  

for folder in os.listdir(train_path):

    sub_path=train_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_train.append(img_arr)

x_test=[]

for folder in os.listdir(test_path):

    sub_path=test_path+"/"+folder

    for img in os.listdir(sub_path):

        image_path=sub_path+"/"+img

        img_arr=cv2.imread(image_path)

        img_arr=cv2.resize(img_arr,(128,128))

        x_test.append(img_arr)

# %%
x_train=np.array(x_train)
x_test=np.array(x_test)

# %%
train_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128, 128),
                                                 batch_size = 500,
                                                 class_mode = 'sparse')
test_set = test_datagen.flow_from_directory(test_path,
                                            target_size = (128, 128),
                                            batch_size = 500,
                                            class_mode = 'sparse')
# Out:
# Found 9921 images belonging to 3 classes.
# Found 1420 images belonging to 3 classes.

# %%
y_train=training_set.classes
y_test=test_set.classes

# %%
NUM_CLASSES = 4
INPUT_SHAPE = (128, 128, 3)


print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
y_train = y_train.reshape((len(y_train), 1))
y_test = y_test.reshape((len(y_test), 1))
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (9921, 128, 128, 3) - y_train shape: (9921,)
# x_test shape: (1420, 128, 128, 3) - y_test shape: (1420,)
# x_train shape: (9921, 128, 128, 3) - y_train shape: (9921, 1)
# x_test shape: (1420, 128, 128, 3) - y_test shape: (1420, 1)

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 500
num_epochs = 200
image_size = 128  # We'll resize input images to this size
patch_size = 16   # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64 
num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 8
mlp_head_units = [2048, 1024]  # Size of the dense layers of the final classifier

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("uint8"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 128 X 128
# Patch size: 16 X 16
# Patches per image: 64
# Elements per patch: 768

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded
def create_vit_classifier():
    inputs = layers.Input(shape=INPUT_SHAPE)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.05)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "Downloads/final_datasets"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.2,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return history

# %%
vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 14s 240ms/step - loss: 2.4867 - accuracy: 0.5053 - top-5-accuracy: 1.0000 - val_loss: 1.7699 - val_accuracy: 0.0856 - val_top-5-accuracy: 1.0000
# Epoch 2/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.7273 - accuracy: 0.6874 - top-5-accuracy: 1.0000 - val_loss: 1.7997 - val_accuracy: 0.2091 - val_top-5-accuracy: 1.0000
# Epoch 3/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.5910 - accuracy: 0.7526 - top-5-accuracy: 1.0000 - val_loss: 1.8194 - val_accuracy: 0.2383 - val_top-5-accuracy: 1.0000
# Epoch 4/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.4927 - accuracy: 0.8033 - top-5-accuracy: 1.0000 - val_loss: 1.7440 - val_accuracy: 0.3229 - val_top-5-accuracy: 1.0000
# Epoch 5/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.4265 - accuracy: 0.8298 - top-5-accuracy: 1.0000 - val_loss: 1.5770 - val_accuracy: 0.5078 - val_top-5-accuracy: 1.0000
# Epoch 6/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.3768 - accuracy: 0.8498 - top-5-accuracy: 1.0000 - val_loss: 2.2890 - val_accuracy: 0.3627 - val_top-5-accuracy: 1.0000
# Epoch 7/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.3278 - accuracy: 0.8698 - top-5-accuracy: 1.0000 - val_loss: 1.5126 - val_accuracy: 0.6262 - val_top-5-accuracy: 1.0000
# Epoch 8/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.3035 - accuracy: 0.8809 - top-5-accuracy: 1.0000 - val_loss: 1.7137 - val_accuracy: 0.5889 - val_top-5-accuracy: 1.0000
# Epoch 9/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.2809 - accuracy: 0.8935 - top-5-accuracy: 1.0000 - val_loss: 1.7595 - val_accuracy: 0.5829 - val_top-5-accuracy: 1.0000
# Epoch 10/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.2654 - accuracy: 0.8957 - top-5-accuracy: 1.0000 - val_loss: 1.6315 - val_accuracy: 0.6640 - val_top-5-accuracy: 1.0000
# Epoch 11/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.2220 - accuracy: 0.9166 - top-5-accuracy: 1.0000 - val_loss: 2.3747 - val_accuracy: 0.5899 - val_top-5-accuracy: 1.0000
# Epoch 12/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.1987 - accuracy: 0.9226 - top-5-accuracy: 1.0000 - val_loss: 1.8831 - val_accuracy: 0.6529 - val_top-5-accuracy: 1.0000
# Epoch 13/200
# 16/16 [==============================] - 3s 172ms/step - loss: 0.1874 - accuracy: 0.9317 - top-5-accuracy: 1.0000 - val_loss: 2.3851 - val_accuracy: 0.6181 - val_top-5-accuracy: 1.0000
# Epoch 14/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.1840 - accuracy: 0.9307 - top-5-accuracy: 1.0000 - val_loss: 1.7098 - val_accuracy: 0.7249 - val_top-5-accuracy: 1.0000
# Epoch 15/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.1564 - accuracy: 0.9432 - top-5-accuracy: 1.0000 - val_loss: 1.8052 - val_accuracy: 0.6922 - val_top-5-accuracy: 1.0000
# Epoch 16/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.1550 - accuracy: 0.9422 - top-5-accuracy: 1.0000 - val_loss: 2.1316 - val_accuracy: 0.7103 - val_top-5-accuracy: 1.0000
# Epoch 17/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.1302 - accuracy: 0.9519 - top-5-accuracy: 1.0000 - val_loss: 2.3324 - val_accuracy: 0.6640 - val_top-5-accuracy: 1.0000
# Epoch 18/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.1230 - accuracy: 0.9559 - top-5-accuracy: 1.0000 - val_loss: 2.2474 - val_accuracy: 0.6811 - val_top-5-accuracy: 1.0000
# Epoch 19/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.1035 - accuracy: 0.9631 - top-5-accuracy: 1.0000 - val_loss: 2.0096 - val_accuracy: 0.7496 - val_top-5-accuracy: 1.0000
# Epoch 20/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0961 - accuracy: 0.9646 - top-5-accuracy: 1.0000 - val_loss: 2.3256 - val_accuracy: 0.6947 - val_top-5-accuracy: 1.0000
# Epoch 21/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.1020 - accuracy: 0.9609 - top-5-accuracy: 1.0000 - val_loss: 2.1141 - val_accuracy: 0.7305 - val_top-5-accuracy: 1.0000
# Epoch 22/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0870 - accuracy: 0.9681 - top-5-accuracy: 1.0000 - val_loss: 2.0434 - val_accuracy: 0.7249 - val_top-5-accuracy: 1.0000
# Epoch 23/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0952 - accuracy: 0.9650 - top-5-accuracy: 1.0000 - val_loss: 2.1887 - val_accuracy: 0.6957 - val_top-5-accuracy: 1.0000
# Epoch 24/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0773 - accuracy: 0.9728 - top-5-accuracy: 1.0000 - val_loss: 2.3401 - val_accuracy: 0.7204 - val_top-5-accuracy: 1.0000
# Epoch 25/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0686 - accuracy: 0.9749 - top-5-accuracy: 1.0000 - val_loss: 2.4436 - val_accuracy: 0.6836 - val_top-5-accuracy: 1.0000
# Epoch 26/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0630 - accuracy: 0.9774 - top-5-accuracy: 1.0000 - val_loss: 2.1948 - val_accuracy: 0.7330 - val_top-5-accuracy: 1.0000
# Epoch 27/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0661 - accuracy: 0.9758 - top-5-accuracy: 1.0000 - val_loss: 2.3370 - val_accuracy: 0.7234 - val_top-5-accuracy: 1.0000
# Epoch 28/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0577 - accuracy: 0.9806 - top-5-accuracy: 1.0000 - val_loss: 2.3940 - val_accuracy: 0.6917 - val_top-5-accuracy: 1.0000
# Epoch 29/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0655 - accuracy: 0.9764 - top-5-accuracy: 1.0000 - val_loss: 2.3462 - val_accuracy: 0.7390 - val_top-5-accuracy: 1.0000
# Epoch 30/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0489 - accuracy: 0.9822 - top-5-accuracy: 1.0000 - val_loss: 2.1884 - val_accuracy: 0.7406 - val_top-5-accuracy: 1.0000
# Epoch 31/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0468 - accuracy: 0.9845 - top-5-accuracy: 1.0000 - val_loss: 2.8250 - val_accuracy: 0.6700 - val_top-5-accuracy: 1.0000
# Epoch 32/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0563 - accuracy: 0.9800 - top-5-accuracy: 1.0000 - val_loss: 2.7562 - val_accuracy: 0.6786 - val_top-5-accuracy: 1.0000
# Epoch 33/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0575 - accuracy: 0.9795 - top-5-accuracy: 1.0000 - val_loss: 2.4537 - val_accuracy: 0.7108 - val_top-5-accuracy: 1.0000
# Epoch 34/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0503 - accuracy: 0.9820 - top-5-accuracy: 1.0000 - val_loss: 2.7564 - val_accuracy: 0.6615 - val_top-5-accuracy: 1.0000
# Epoch 35/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0408 - accuracy: 0.9861 - top-5-accuracy: 1.0000 - val_loss: 2.3863 - val_accuracy: 0.7340 - val_top-5-accuracy: 1.0000
# Epoch 36/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0367 - accuracy: 0.9880 - top-5-accuracy: 1.0000 - val_loss: 2.3110 - val_accuracy: 0.7340 - val_top-5-accuracy: 1.0000
# Epoch 37/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0341 - accuracy: 0.9879 - top-5-accuracy: 1.0000 - val_loss: 2.8535 - val_accuracy: 0.7390 - val_top-5-accuracy: 1.0000
# Epoch 38/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0390 - accuracy: 0.9864 - top-5-accuracy: 1.0000 - val_loss: 2.5402 - val_accuracy: 0.7652 - val_top-5-accuracy: 1.0000
# Epoch 39/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0312 - accuracy: 0.9889 - top-5-accuracy: 1.0000 - val_loss: 2.7374 - val_accuracy: 0.7340 - val_top-5-accuracy: 1.0000
# Epoch 40/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0302 - accuracy: 0.9898 - top-5-accuracy: 1.0000 - val_loss: 2.6940 - val_accuracy: 0.7184 - val_top-5-accuracy: 1.0000
# Epoch 41/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0296 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 3.0559 - val_accuracy: 0.6776 - val_top-5-accuracy: 1.0000
# Epoch 42/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0340 - accuracy: 0.9859 - top-5-accuracy: 1.0000 - val_loss: 3.5192 - val_accuracy: 0.6176 - val_top-5-accuracy: 1.0000
# Epoch 43/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0321 - accuracy: 0.9879 - top-5-accuracy: 1.0000 - val_loss: 3.7195 - val_accuracy: 0.6035 - val_top-5-accuracy: 1.0000
# Epoch 44/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0300 - accuracy: 0.9905 - top-5-accuracy: 1.0000 - val_loss: 2.5267 - val_accuracy: 0.7103 - val_top-5-accuracy: 1.0000
# Epoch 45/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0311 - accuracy: 0.9889 - top-5-accuracy: 1.0000 - val_loss: 2.6323 - val_accuracy: 0.7325 - val_top-5-accuracy: 1.0000
# Epoch 46/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0263 - accuracy: 0.9914 - top-5-accuracy: 1.0000 - val_loss: 2.7574 - val_accuracy: 0.7244 - val_top-5-accuracy: 1.0000
# Epoch 47/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0267 - accuracy: 0.9913 - top-5-accuracy: 1.0000 - val_loss: 3.1974 - val_accuracy: 0.6877 - val_top-5-accuracy: 1.0000
# Epoch 48/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0333 - accuracy: 0.9894 - top-5-accuracy: 1.0000 - val_loss: 2.6386 - val_accuracy: 0.7562 - val_top-5-accuracy: 1.0000
# Epoch 49/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0291 - accuracy: 0.9902 - top-5-accuracy: 1.0000 - val_loss: 2.8624 - val_accuracy: 0.7315 - val_top-5-accuracy: 1.0000
# Epoch 50/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0236 - accuracy: 0.9916 - top-5-accuracy: 1.0000 - val_loss: 2.8668 - val_accuracy: 0.7093 - val_top-5-accuracy: 1.0000
# Epoch 51/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0204 - accuracy: 0.9932 - top-5-accuracy: 1.0000 - val_loss: 3.1467 - val_accuracy: 0.7083 - val_top-5-accuracy: 1.0000
# Epoch 52/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0228 - accuracy: 0.9914 - top-5-accuracy: 1.0000 - val_loss: 3.0129 - val_accuracy: 0.7264 - val_top-5-accuracy: 1.0000
# Epoch 53/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0235 - accuracy: 0.9922 - top-5-accuracy: 1.0000 - val_loss: 2.6826 - val_accuracy: 0.7708 - val_top-5-accuracy: 1.0000
# Epoch 54/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0258 - accuracy: 0.9908 - top-5-accuracy: 1.0000 - val_loss: 2.8755 - val_accuracy: 0.7305 - val_top-5-accuracy: 1.0000
# Epoch 55/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0190 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 3.0197 - val_accuracy: 0.7768 - val_top-5-accuracy: 1.0000
# Epoch 56/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0221 - accuracy: 0.9924 - top-5-accuracy: 1.0000 - val_loss: 3.1821 - val_accuracy: 0.6902 - val_top-5-accuracy: 1.0000
# Epoch 57/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0231 - accuracy: 0.9919 - top-5-accuracy: 1.0000 - val_loss: 2.7609 - val_accuracy: 0.7501 - val_top-5-accuracy: 1.0000
# Epoch 58/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0157 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 3.0761 - val_accuracy: 0.7466 - val_top-5-accuracy: 1.0000
# Epoch 59/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0292 - accuracy: 0.9899 - top-5-accuracy: 1.0000 - val_loss: 2.9611 - val_accuracy: 0.7108 - val_top-5-accuracy: 1.0000
# Epoch 60/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0193 - accuracy: 0.9926 - top-5-accuracy: 1.0000 - val_loss: 2.7447 - val_accuracy: 0.7783 - val_top-5-accuracy: 1.0000
# Epoch 61/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0180 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 2.9414 - val_accuracy: 0.7587 - val_top-5-accuracy: 1.0000
# Epoch 62/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0155 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 3.1475 - val_accuracy: 0.7426 - val_top-5-accuracy: 1.0000
# Epoch 63/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0184 - accuracy: 0.9934 - top-5-accuracy: 1.0000 - val_loss: 3.2662 - val_accuracy: 0.7355 - val_top-5-accuracy: 1.0000
# Epoch 64/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0197 - accuracy: 0.9931 - top-5-accuracy: 1.0000 - val_loss: 3.1832 - val_accuracy: 0.7219 - val_top-5-accuracy: 1.0000
# Epoch 65/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0263 - accuracy: 0.9903 - top-5-accuracy: 1.0000 - val_loss: 3.5434 - val_accuracy: 0.6952 - val_top-5-accuracy: 1.0000
# Epoch 66/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0217 - accuracy: 0.9922 - top-5-accuracy: 1.0000 - val_loss: 3.5998 - val_accuracy: 0.6801 - val_top-5-accuracy: 1.0000
# Epoch 67/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0200 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 3.0747 - val_accuracy: 0.7275 - val_top-5-accuracy: 1.0000
# Epoch 68/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0267 - accuracy: 0.9911 - top-5-accuracy: 1.0000 - val_loss: 2.5583 - val_accuracy: 0.7733 - val_top-5-accuracy: 1.0000
# Epoch 69/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0210 - accuracy: 0.9928 - top-5-accuracy: 1.0000 - val_loss: 3.1746 - val_accuracy: 0.7481 - val_top-5-accuracy: 1.0000
# Epoch 70/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0185 - accuracy: 0.9942 - top-5-accuracy: 1.0000 - val_loss: 2.8391 - val_accuracy: 0.7622 - val_top-5-accuracy: 1.0000
# Epoch 71/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0168 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 3.5461 - val_accuracy: 0.7013 - val_top-5-accuracy: 1.0000
# Epoch 72/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0157 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 3.8774 - val_accuracy: 0.6892 - val_top-5-accuracy: 1.0000
# Epoch 73/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0194 - accuracy: 0.9945 - top-5-accuracy: 1.0000 - val_loss: 3.4034 - val_accuracy: 0.6786 - val_top-5-accuracy: 1.0000
# Epoch 74/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0167 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 3.0809 - val_accuracy: 0.7521 - val_top-5-accuracy: 1.0000
# Epoch 75/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0165 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 2.7409 - val_accuracy: 0.7557 - val_top-5-accuracy: 1.0000
# Epoch 76/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0129 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 3.2140 - val_accuracy: 0.7526 - val_top-5-accuracy: 1.0000
# Epoch 77/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0128 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 3.1636 - val_accuracy: 0.7562 - val_top-5-accuracy: 1.0000
# Epoch 78/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0175 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 2.6498 - val_accuracy: 0.7773 - val_top-5-accuracy: 1.0000
# Epoch 79/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0216 - accuracy: 0.9922 - top-5-accuracy: 1.0000 - val_loss: 3.1055 - val_accuracy: 0.6912 - val_top-5-accuracy: 1.0000
# Epoch 80/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0144 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 3.2386 - val_accuracy: 0.7259 - val_top-5-accuracy: 1.0000
# Epoch 81/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0163 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 2.9856 - val_accuracy: 0.7778 - val_top-5-accuracy: 1.0000
# Epoch 82/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0120 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 3.4776 - val_accuracy: 0.7537 - val_top-5-accuracy: 1.0000
# Epoch 83/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0165 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 2.8899 - val_accuracy: 0.7668 - val_top-5-accuracy: 1.0000
# Epoch 84/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0109 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 2.9429 - val_accuracy: 0.7637 - val_top-5-accuracy: 1.0000
# Epoch 85/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0141 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 3.3651 - val_accuracy: 0.7481 - val_top-5-accuracy: 1.0000
# Epoch 86/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0213 - accuracy: 0.9946 - top-5-accuracy: 1.0000 - val_loss: 2.7758 - val_accuracy: 0.7743 - val_top-5-accuracy: 1.0000
# Epoch 87/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0177 - accuracy: 0.9936 - top-5-accuracy: 1.0000 - val_loss: 3.3434 - val_accuracy: 0.6650 - val_top-5-accuracy: 1.0000
# Epoch 88/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0147 - accuracy: 0.9957 - top-5-accuracy: 1.0000 - val_loss: 2.7160 - val_accuracy: 0.7401 - val_top-5-accuracy: 1.0000
# Epoch 89/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0222 - accuracy: 0.9921 - top-5-accuracy: 1.0000 - val_loss: 3.2843 - val_accuracy: 0.7743 - val_top-5-accuracy: 1.0000
# Epoch 90/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0182 - accuracy: 0.9940 - top-5-accuracy: 1.0000 - val_loss: 3.0126 - val_accuracy: 0.7884 - val_top-5-accuracy: 1.0000
# Epoch 91/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0175 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 2.8228 - val_accuracy: 0.7788 - val_top-5-accuracy: 1.0000
# Epoch 92/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0186 - accuracy: 0.9924 - top-5-accuracy: 1.0000 - val_loss: 4.0336 - val_accuracy: 0.6877 - val_top-5-accuracy: 1.0000
# Epoch 93/200
# 16/16 [==============================] - 3s 174ms/step - loss: 0.0156 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 3.5064 - val_accuracy: 0.7088 - val_top-5-accuracy: 1.0000
# Epoch 94/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0115 - accuracy: 0.9962 - top-5-accuracy: 1.0000 - val_loss: 3.5662 - val_accuracy: 0.7264 - val_top-5-accuracy: 1.0000
# Epoch 95/200
# 16/16 [==============================] - 3s 175ms/step - loss: 0.0141 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 3.6652 - val_accuracy: 0.7305 - val_top-5-accuracy: 1.0000
# Epoch 96/200
# 16/16 [==============================] - 3s 171ms/step - loss: 0.0157 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.4494 - val_accuracy: 0.7229 - val_top-5-accuracy: 1.0000
# Epoch 97/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0139 - accuracy: 0.9957 - top-5-accuracy: 1.0000 - val_loss: 3.6742 - val_accuracy: 0.6952 - val_top-5-accuracy: 1.0000
# Epoch 98/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0120 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 3.7111 - val_accuracy: 0.7219 - val_top-5-accuracy: 1.0000
# Epoch 99/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0126 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 3.5077 - val_accuracy: 0.7214 - val_top-5-accuracy: 1.0000
# Epoch 100/200
# 16/16 [==============================] - 3s 170ms/step - loss: 0.0092 - accuracy: 0.9970 - top-5-accuracy: 1.0000 - val_loss: 3.3042 - val_accuracy: 0.7521 - val_top-5-accuracy: 1.0000
# Epoch 101/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0085 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 4.4661 - val_accuracy: 0.6690 - val_top-5-accuracy: 1.0000
# Epoch 102/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0117 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 3.9136 - val_accuracy: 0.7295 - val_top-5-accuracy: 1.0000
# Epoch 103/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0116 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 3.7204 - val_accuracy: 0.6645 - val_top-5-accuracy: 1.0000
# Epoch 104/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0111 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 3.2686 - val_accuracy: 0.7783 - val_top-5-accuracy: 1.0000
# Epoch 105/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0111 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 2.9920 - val_accuracy: 0.7955 - val_top-5-accuracy: 1.0000
# Epoch 106/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0153 - accuracy: 0.9945 - top-5-accuracy: 1.0000 - val_loss: 3.7545 - val_accuracy: 0.7380 - val_top-5-accuracy: 1.0000
# Epoch 107/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0100 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 3.6772 - val_accuracy: 0.7123 - val_top-5-accuracy: 1.0000
# Epoch 108/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0105 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 3.9676 - val_accuracy: 0.7078 - val_top-5-accuracy: 1.0000
# Epoch 109/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0092 - accuracy: 0.9966 - top-5-accuracy: 1.0000 - val_loss: 3.5246 - val_accuracy: 0.7310 - val_top-5-accuracy: 1.0000
# Epoch 110/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0095 - accuracy: 0.9974 - top-5-accuracy: 1.0000 - val_loss: 4.0082 - val_accuracy: 0.6569 - val_top-5-accuracy: 1.0000
# Epoch 111/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0113 - accuracy: 0.9955 - top-5-accuracy: 1.0000 - val_loss: 3.7696 - val_accuracy: 0.6922 - val_top-5-accuracy: 1.0000
# Epoch 112/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0138 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.3291 - val_accuracy: 0.7118 - val_top-5-accuracy: 1.0000
# Epoch 113/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0162 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.0843 - val_accuracy: 0.7431 - val_top-5-accuracy: 1.0000
# Epoch 114/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0113 - accuracy: 0.9962 - top-5-accuracy: 1.0000 - val_loss: 3.6248 - val_accuracy: 0.7355 - val_top-5-accuracy: 1.0000
# Epoch 115/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0082 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 3.7606 - val_accuracy: 0.7395 - val_top-5-accuracy: 1.0000
# Epoch 116/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0146 - accuracy: 0.9955 - top-5-accuracy: 1.0000 - val_loss: 2.7127 - val_accuracy: 0.7139 - val_top-5-accuracy: 1.0000
# Epoch 117/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0170 - accuracy: 0.9943 - top-5-accuracy: 1.0000 - val_loss: 3.1782 - val_accuracy: 0.7360 - val_top-5-accuracy: 1.0000
# Epoch 118/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0132 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 3.2050 - val_accuracy: 0.7577 - val_top-5-accuracy: 1.0000
# Epoch 119/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0175 - accuracy: 0.9945 - top-5-accuracy: 1.0000 - val_loss: 3.4118 - val_accuracy: 0.7048 - val_top-5-accuracy: 1.0000
# Epoch 120/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0152 - accuracy: 0.9948 - top-5-accuracy: 1.0000 - val_loss: 3.6972 - val_accuracy: 0.7139 - val_top-5-accuracy: 1.0000
# Epoch 121/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0229 - accuracy: 0.9933 - top-5-accuracy: 1.0000 - val_loss: 3.4557 - val_accuracy: 0.6453 - val_top-5-accuracy: 1.0000
# Epoch 122/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0221 - accuracy: 0.9927 - top-5-accuracy: 1.0000 - val_loss: 2.7859 - val_accuracy: 0.7134 - val_top-5-accuracy: 1.0000
# Epoch 123/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0129 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 3.0175 - val_accuracy: 0.6972 - val_top-5-accuracy: 1.0000
# Epoch 124/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0098 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.1351 - val_accuracy: 0.7401 - val_top-5-accuracy: 1.0000
# Epoch 125/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0066 - accuracy: 0.9977 - top-5-accuracy: 1.0000 - val_loss: 3.8223 - val_accuracy: 0.6962 - val_top-5-accuracy: 1.0000
# Epoch 126/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0087 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 3.2887 - val_accuracy: 0.7577 - val_top-5-accuracy: 1.0000
# Epoch 127/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0055 - accuracy: 0.9984 - top-5-accuracy: 1.0000 - val_loss: 3.5245 - val_accuracy: 0.7229 - val_top-5-accuracy: 1.0000
# Epoch 128/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0061 - accuracy: 0.9974 - top-5-accuracy: 1.0000 - val_loss: 4.2961 - val_accuracy: 0.6781 - val_top-5-accuracy: 1.0000
# Epoch 129/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0092 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.4044 - val_accuracy: 0.6786 - val_top-5-accuracy: 1.0000
# Epoch 130/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0119 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 3.6247 - val_accuracy: 0.7345 - val_top-5-accuracy: 1.0000
# Epoch 131/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0111 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 3.5696 - val_accuracy: 0.7295 - val_top-5-accuracy: 1.0000
# Epoch 132/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0103 - accuracy: 0.9956 - top-5-accuracy: 1.0000 - val_loss: 3.1368 - val_accuracy: 0.6720 - val_top-5-accuracy: 1.0000
# Epoch 133/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0138 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 3.3756 - val_accuracy: 0.7093 - val_top-5-accuracy: 1.0000
# Epoch 134/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0178 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 3.0070 - val_accuracy: 0.7607 - val_top-5-accuracy: 1.0000
# Epoch 135/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0130 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 3.5303 - val_accuracy: 0.7879 - val_top-5-accuracy: 1.0000
# Epoch 136/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0080 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 3.7325 - val_accuracy: 0.7239 - val_top-5-accuracy: 1.0000
# Epoch 137/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0098 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.5453 - val_accuracy: 0.7441 - val_top-5-accuracy: 1.0000
# Epoch 138/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0120 - accuracy: 0.9962 - top-5-accuracy: 1.0000 - val_loss: 3.8640 - val_accuracy: 0.7264 - val_top-5-accuracy: 1.0000
# Epoch 139/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0069 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 3.5281 - val_accuracy: 0.7693 - val_top-5-accuracy: 1.0000
# Epoch 140/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0096 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 3.3420 - val_accuracy: 0.7169 - val_top-5-accuracy: 1.0000
# Epoch 141/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0180 - accuracy: 0.9937 - top-5-accuracy: 1.0000 - val_loss: 3.3071 - val_accuracy: 0.7773 - val_top-5-accuracy: 1.0000
# Epoch 142/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0246 - accuracy: 0.9919 - top-5-accuracy: 1.0000 - val_loss: 3.3432 - val_accuracy: 0.7219 - val_top-5-accuracy: 1.0000
# Epoch 143/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0154 - accuracy: 0.9950 - top-5-accuracy: 1.0000 - val_loss: 3.1535 - val_accuracy: 0.7224 - val_top-5-accuracy: 1.0000
# Epoch 144/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0267 - accuracy: 0.9909 - top-5-accuracy: 1.0000 - val_loss: 2.5008 - val_accuracy: 0.7743 - val_top-5-accuracy: 1.0000
# Epoch 145/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0234 - accuracy: 0.9923 - top-5-accuracy: 1.0000 - val_loss: 3.4999 - val_accuracy: 0.6856 - val_top-5-accuracy: 1.0000
# Epoch 146/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0140 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.2484 - val_accuracy: 0.7199 - val_top-5-accuracy: 1.0000
# Epoch 147/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0094 - accuracy: 0.9975 - top-5-accuracy: 1.0000 - val_loss: 3.5661 - val_accuracy: 0.7103 - val_top-5-accuracy: 1.0000
# Epoch 148/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0095 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 3.8576 - val_accuracy: 0.6736 - val_top-5-accuracy: 1.0000
# Epoch 149/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0125 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 3.6815 - val_accuracy: 0.6605 - val_top-5-accuracy: 1.0000
# Epoch 150/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0123 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 3.2033 - val_accuracy: 0.7894 - val_top-5-accuracy: 1.0000
# Epoch 151/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0088 - accuracy: 0.9966 - top-5-accuracy: 1.0000 - val_loss: 3.7426 - val_accuracy: 0.7058 - val_top-5-accuracy: 1.0000
# Epoch 152/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0062 - accuracy: 0.9980 - top-5-accuracy: 1.0000 - val_loss: 3.9262 - val_accuracy: 0.7224 - val_top-5-accuracy: 1.0000
# Epoch 153/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0086 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 3.4600 - val_accuracy: 0.7385 - val_top-5-accuracy: 1.0000
# Epoch 154/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0134 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 3.7408 - val_accuracy: 0.6806 - val_top-5-accuracy: 1.0000
# Epoch 155/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0130 - accuracy: 0.9951 - top-5-accuracy: 1.0000 - val_loss: 4.3502 - val_accuracy: 0.6418 - val_top-5-accuracy: 1.0000
# Epoch 156/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0115 - accuracy: 0.9958 - top-5-accuracy: 1.0000 - val_loss: 4.3098 - val_accuracy: 0.6000 - val_top-5-accuracy: 1.0000
# Epoch 157/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0149 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 3.6694 - val_accuracy: 0.7194 - val_top-5-accuracy: 1.0000
# Epoch 158/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0101 - accuracy: 0.9970 - top-5-accuracy: 1.0000 - val_loss: 3.3629 - val_accuracy: 0.7451 - val_top-5-accuracy: 1.0000
# Epoch 159/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0066 - accuracy: 0.9980 - top-5-accuracy: 1.0000 - val_loss: 3.8243 - val_accuracy: 0.7139 - val_top-5-accuracy: 1.0000
# Epoch 160/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0089 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 3.9644 - val_accuracy: 0.7149 - val_top-5-accuracy: 1.0000
# Epoch 161/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0075 - accuracy: 0.9981 - top-5-accuracy: 1.0000 - val_loss: 4.0908 - val_accuracy: 0.6932 - val_top-5-accuracy: 1.0000
# Epoch 162/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0142 - accuracy: 0.9952 - top-5-accuracy: 1.0000 - val_loss: 4.0334 - val_accuracy: 0.7239 - val_top-5-accuracy: 1.0000
# Epoch 163/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0117 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 4.1335 - val_accuracy: 0.6599 - val_top-5-accuracy: 1.0000
# Epoch 164/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0072 - accuracy: 0.9975 - top-5-accuracy: 1.0000 - val_loss: 3.6065 - val_accuracy: 0.7476 - val_top-5-accuracy: 1.0000
# Epoch 165/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0073 - accuracy: 0.9974 - top-5-accuracy: 1.0000 - val_loss: 4.0879 - val_accuracy: 0.7285 - val_top-5-accuracy: 1.0000
# Epoch 166/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0091 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 3.7191 - val_accuracy: 0.7491 - val_top-5-accuracy: 1.0000
# Epoch 167/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0107 - accuracy: 0.9965 - top-5-accuracy: 1.0000 - val_loss: 3.3037 - val_accuracy: 0.7204 - val_top-5-accuracy: 1.0000
# Epoch 168/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0102 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 3.7778 - val_accuracy: 0.7360 - val_top-5-accuracy: 1.0000
# Epoch 169/200
# 16/16 [==============================] - 3s 169ms/step - loss: 0.0082 - accuracy: 0.9966 - top-5-accuracy: 1.0000 - val_loss: 3.7108 - val_accuracy: 0.6907 - val_top-5-accuracy: 1.0000
# Epoch 170/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0102 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 3.2046 - val_accuracy: 0.7748 - val_top-5-accuracy: 1.0000
# Epoch 171/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0085 - accuracy: 0.9974 - top-5-accuracy: 1.0000 - val_loss: 3.1661 - val_accuracy: 0.7451 - val_top-5-accuracy: 1.0000
# Epoch 172/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0112 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.7865 - val_accuracy: 0.6700 - val_top-5-accuracy: 1.0000
# Epoch 173/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0127 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 3.7881 - val_accuracy: 0.7068 - val_top-5-accuracy: 1.0000
# Epoch 174/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0112 - accuracy: 0.9963 - top-5-accuracy: 1.0000 - val_loss: 3.5730 - val_accuracy: 0.7401 - val_top-5-accuracy: 1.0000
# Epoch 175/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0202 - accuracy: 0.9933 - top-5-accuracy: 1.0000 - val_loss: 4.7936 - val_accuracy: 0.5174 - val_top-5-accuracy: 1.0000
# Epoch 176/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0172 - accuracy: 0.9941 - top-5-accuracy: 1.0000 - val_loss: 2.8062 - val_accuracy: 0.7708 - val_top-5-accuracy: 1.0000
# Epoch 177/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0133 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 3.4338 - val_accuracy: 0.7662 - val_top-5-accuracy: 1.0000
# Epoch 178/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0114 - accuracy: 0.9960 - top-5-accuracy: 1.0000 - val_loss: 3.9263 - val_accuracy: 0.6741 - val_top-5-accuracy: 1.0000
# Epoch 179/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0130 - accuracy: 0.9953 - top-5-accuracy: 1.0000 - val_loss: 3.9816 - val_accuracy: 0.7023 - val_top-5-accuracy: 1.0000
# Epoch 180/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0078 - accuracy: 0.9974 - top-5-accuracy: 1.0000 - val_loss: 3.5847 - val_accuracy: 0.7270 - val_top-5-accuracy: 1.0000
# Epoch 181/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0070 - accuracy: 0.9977 - top-5-accuracy: 1.0000 - val_loss: 3.3127 - val_accuracy: 0.7662 - val_top-5-accuracy: 1.0000
# Epoch 182/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0079 - accuracy: 0.9975 - top-5-accuracy: 1.0000 - val_loss: 4.0192 - val_accuracy: 0.7244 - val_top-5-accuracy: 1.0000
# Epoch 183/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0082 - accuracy: 0.9976 - top-5-accuracy: 1.0000 - val_loss: 4.2083 - val_accuracy: 0.7134 - val_top-5-accuracy: 1.0000
# Epoch 184/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0085 - accuracy: 0.9967 - top-5-accuracy: 1.0000 - val_loss: 3.3672 - val_accuracy: 0.7622 - val_top-5-accuracy: 1.0000
# Epoch 185/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0114 - accuracy: 0.9971 - top-5-accuracy: 1.0000 - val_loss: 2.9597 - val_accuracy: 0.7854 - val_top-5-accuracy: 1.0000
# Epoch 186/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0129 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 3.1207 - val_accuracy: 0.7607 - val_top-5-accuracy: 1.0000
# Epoch 187/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0115 - accuracy: 0.9962 - top-5-accuracy: 1.0000 - val_loss: 3.8833 - val_accuracy: 0.6771 - val_top-5-accuracy: 1.0000
# Epoch 188/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0081 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 3.9510 - val_accuracy: 0.7521 - val_top-5-accuracy: 1.0000
# Epoch 189/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0084 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 3.7585 - val_accuracy: 0.7264 - val_top-5-accuracy: 1.0000
# Epoch 190/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0070 - accuracy: 0.9981 - top-5-accuracy: 1.0000 - val_loss: 3.4942 - val_accuracy: 0.7008 - val_top-5-accuracy: 1.0000
# Epoch 191/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0064 - accuracy: 0.9980 - top-5-accuracy: 1.0000 - val_loss: 4.4988 - val_accuracy: 0.6912 - val_top-5-accuracy: 1.0000
# Epoch 192/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0110 - accuracy: 0.9962 - top-5-accuracy: 1.0000 - val_loss: 4.5804 - val_accuracy: 0.7290 - val_top-5-accuracy: 1.0000
# Epoch 193/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0056 - accuracy: 0.9984 - top-5-accuracy: 1.0000 - val_loss: 3.7189 - val_accuracy: 0.7642 - val_top-5-accuracy: 1.0000
# Epoch 194/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0073 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 4.0307 - val_accuracy: 0.6977 - val_top-5-accuracy: 1.0000
# Epoch 195/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0065 - accuracy: 0.9968 - top-5-accuracy: 1.0000 - val_loss: 3.8921 - val_accuracy: 0.7068 - val_top-5-accuracy: 1.0000
# Epoch 196/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0057 - accuracy: 0.9980 - top-5-accuracy: 1.0000 - val_loss: 3.7654 - val_accuracy: 0.6630 - val_top-5-accuracy: 1.0000
# Epoch 197/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0086 - accuracy: 0.9972 - top-5-accuracy: 1.0000 - val_loss: 3.7180 - val_accuracy: 0.7214 - val_top-5-accuracy: 1.0000
# Epoch 198/200
# 16/16 [==============================] - 3s 168ms/step - loss: 0.0110 - accuracy: 0.9966 - top-5-accuracy: 1.0000 - val_loss: 3.9551 - val_accuracy: 0.6287 - val_top-5-accuracy: 1.0000
# Epoch 199/200
# 16/16 [==============================] - 3s 167ms/step - loss: 0.0127 - accuracy: 0.9961 - top-5-accuracy: 1.0000 - val_loss: 3.2302 - val_accuracy: 0.7375 - val_top-5-accuracy: 1.0000
# Epoch 200/200
# 16/16 [==============================] - 3s 166ms/step - loss: 0.0181 - accuracy: 0.9947 - top-5-accuracy: 1.0000 - val_loss: 3.2101 - val_accuracy: 0.6846 - val_top-5-accuracy: 1.0000
# 45/45 [==============================] - 1s 20ms/step - loss: 0.4925 - accuracy: 0.9563 - top-5-accuracy: 1.0000
# Test accuracy: 95.63%
# Test top 5 accuracy: 100.0%

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
import matplotlib as mpl
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
mpl.rcParams["figure.dpi"] = 300
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
mpl.rcParams["figure.dpi"] = 300
plt.legend(['Train', 'Test'], loc='upper left')
mpl.rcParams["font.serif"] = "Times New Roman"
mpl.rcParams['font.family'] = "Times New Roman"
plt.legend(['train', 'test'], loc='upper left')
plt.grid()
plt.show()

# %%
# p = Augmentor.Pipeline("3D Objects/raw/",output_directory="../New_folder")
# #Step 3 Define the Operations
# p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
# p.zoom(probability=0.3, min_factor=1.1, max_factor=1.6)
# p.sample(800)

import pathlib
import tensorflow as tf

data_dir = pathlib.Path('./Downloads/Final_Train_Test_thesis2.0/train')

img_height=128
img_width=128


train_ds  = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=500)
# Out:
# Found 9921 files belonging to 3 classes.
# Using 7937 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=32)

normalization_layer = tf.keras.layers.Rescaling(1./255)


import numpy as np
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))


AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 9921 files belonging to 3 classes.
# Using 1984 files for validation.
# 0.004901961 1.0

# %%
train_label = np.concatenate([y for x, y in train_ds], axis=0)
print(train_label.shape)

test_label = np.concatenate([y for x, y in val_ds], axis=0) 
print(test_label.shape)
# Out:
# (7937,)
# (1984,)

# %%
import scipy
# if this works
from scipy.sparse import issparse

# %%
# !pip install scikit-learn
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
#Confution Matrix and Classification Report
import matplotlib.pyplot as plt
Y_pred = vit_classifier.predict_generator(val_ds, 700)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
cm=confusion_matrix(test_label, y_pred)
print(cm)
print('Classification Report')
target_names = ['Flood', 'Flood_with_habitation', 'No_Flood']
#target_names = ['Normal','Glocoman']
print(classification_report(test_label, y_pred, target_names=target_names))
# Out:
# Requirement already satisfied: scikit-learn in c:\users\20101621\.conda\envs\new_env\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from scikit-learn) (1.10.1)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# C:\Users\20101621\.conda\envs\new_env\lib\site-packages\keras\engine\training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 700 batches). You may need to use the repeat() function when building your dataset.
# Confusion Matrix
# [[655   0   0]
#  [  0 717   0]
#  [ 57  21 534]]
# Classification Report
#                        precision    recall  f1-score   support
#
#                 Flood       0.92      1.00      0.96       655
# Flood_with_habitation       0.97      1.00      0.99       717
#              No_Flood       1.00      0.87      0.93       612
#
#              accuracy                           0.96      1984
#             macro avg       0.96      0.96      0.96      1984
#          weighted avg       0.96      0.96      0.96      1984

# %%
# !pip install seaborn
import seaborn as sns
sns.set(font_scale=1.0)
ax=sns.heatmap(cm, annot=True, cmap='summer', cbar=False, linewidths=3, linecolor='r', square=True, xticklabels=target_names,yticklabels=target_names,fmt='')
#sns.heatmap(cm, annot=True,annot_kws={"size": 22})
sns.set(font_scale = 2.0)
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nActual Values')
ax.set_ylabel('Predicted Values ');
# Out:
# Requirement already satisfied: seaborn in c:\users\20101621\.conda\envs\new_env\lib\site-packages (0.12.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\20101621\.conda\envs\new_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\20101621\.conda\envs\new_env\lib\site-packages)

# %%
vit_classifier.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# data_augmentation (Sequential)  (None, 128, 128, 3)  7           input_2[0][0]
# __________________________________________________________________________________________________
# patches_3 (Patches)             (None, None, 768)    0           data_augmentation[0][0]
# __________________________________________________________________________________________________
# patch_encoder_1 (PatchEncoder)  (None, 64, 64)       53312       patches_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 64, 64)       128         patch_encoder_1[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_8 (MultiHe (None, 64, 64)       66368       layer_normalization_17[0][0]
#                                                                  layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 64, 64)       0           multi_head_attention_8[0][0]
#                                                                  patch_encoder_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 64, 64)       128         add_16[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 64, 128)      8320        layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 64, 128)      0           dense_21[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 64, 64)       8256        dropout_19[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 64, 64)       0           dense_22[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 64)       0           dropout_20[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 64, 64)       128         add_17[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_9 (MultiHe (None, 64, 64)       66368       layer_normalization_19[0][0]
#                                                                  layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 64, 64)       0           multi_head_attention_9[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# layer_normalization_20 (LayerNo (None, 64, 64)       128         add_18[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 64, 128)      8320        layer_normalization_20[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 64, 128)      0           dense_23[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 64, 64)       8256        dropout_21[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 64, 64)       0           dense_24[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 64, 64)       0           dropout_22[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_21 (LayerNo (None, 64, 64)       128         add_19[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_10 (MultiH (None, 64, 64)       66368       layer_normalization_21[0][0]
#                                                                  layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 64, 64)       0           multi_head_attention_10[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization_22 (LayerNo (None, 64, 64)       128         add_20[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 64, 128)      8320        layer_normalization_22[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 64, 128)      0           dense_25[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 64, 64)       8256        dropout_23[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 64, 64)       0           dense_26[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 64, 64)       0           dropout_24[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# layer_normalization_23 (LayerNo (None, 64, 64)       128         add_21[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_11 (MultiH (None, 64, 64)       66368       layer_normalization_23[0][0]
#                                                                  layer_normalization_23[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 64, 64)       0           multi_head_attention_11[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_24 (LayerNo (None, 64, 64)       128         add_22[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 64, 128)      8320        layer_normalization_24[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 64, 128)      0           dense_27[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 64, 64)       8256        dropout_25[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 64, 64)       0           dense_28[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 64, 64)       0           dropout_26[0][0]
#                                                                  add_22[0][0]
# __________________________________________________________________________________________________
# layer_normalization_25 (LayerNo (None, 64, 64)       128         add_23[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_12 (MultiH (None, 64, 64)       66368       layer_normalization_25[0][0]
#                                                                  layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 64, 64)       0           multi_head_attention_12[0][0]
#                                                                  add_23[0][0]
# __________________________________________________________________________________________________
# layer_normalization_26 (LayerNo (None, 64, 64)       128         add_24[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 64, 128)      8320        layer_normalization_26[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 64, 128)      0           dense_29[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 64, 64)       8256        dropout_27[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 64, 64)       0           dense_30[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 64, 64)       0           dropout_28[0][0]
#                                                                  add_24[0][0]
# __________________________________________________________________________________________________
# layer_normalization_27 (LayerNo (None, 64, 64)       128         add_25[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_13 (MultiH (None, 64, 64)       66368       layer_normalization_27[0][0]
#                                                                  layer_normalization_27[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 64, 64)       0           multi_head_attention_13[0][0]
#                                                                  add_25[0][0]
# __________________________________________________________________________________________________
# layer_normalization_28 (LayerNo (None, 64, 64)       128         add_26[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 64, 128)      8320        layer_normalization_28[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 64, 128)      0           dense_31[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 64, 64)       8256        dropout_29[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 64, 64)       0           dense_32[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 64, 64)       0           dropout_30[0][0]
#                                                                  add_26[0][0]
# __________________________________________________________________________________________________
# layer_normalization_29 (LayerNo (None, 64, 64)       128         add_27[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_14 (MultiH (None, 64, 64)       66368       layer_normalization_29[0][0]
#                                                                  layer_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 64, 64)       0           multi_head_attention_14[0][0]
#                                                                  add_27[0][0]
# __________________________________________________________________________________________________
# layer_normalization_30 (LayerNo (None, 64, 64)       128         add_28[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 64, 128)      8320        layer_normalization_30[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 64, 128)      0           dense_33[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 64, 64)       8256        dropout_31[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 64, 64)       0           dense_34[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 64, 64)       0           dropout_32[0][0]
#                                                                  add_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_31 (LayerNo (None, 64, 64)       128         add_29[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_15 (MultiH (None, 64, 64)       66368       layer_normalization_31[0][0]
#                                                                  layer_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 64, 64)       0           multi_head_attention_15[0][0]
#                                                                  add_29[0][0]
# __________________________________________________________________________________________________
# layer_normalization_32 (LayerNo (None, 64, 64)       128         add_30[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 64, 128)      8320        layer_normalization_32[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 64, 128)      0           dense_35[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 64, 64)       8256        dropout_33[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 64, 64)       0           dense_36[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 64, 64)       0           dropout_34[0][0]
#                                                                  add_30[0][0]
# __________________________________________________________________________________________________
# layer_normalization_33 (LayerNo (None, 64, 64)       128         add_31[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 4096)         0           layer_normalization_33[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 4096)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 2048)         8390656     dropout_35[0][0]
# __________________________________________________________________________________________________
# dropout_36 (Dropout)            (None, 2048)         0           dense_37[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 1024)         2098176     dropout_36[0][0]
# __________________________________________________________________________________________________
# dropout_37 (Dropout)            (None, 1024)         0           dense_38[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 4)            4100        dropout_37[0][0]
# ==================================================================================================
# Total params: 11,211,979
# Trainable params: 11,211,972
# Non-trainable params: 7
# __________________________________________________________________________________________________
